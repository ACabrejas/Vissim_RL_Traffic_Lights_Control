# %%
######################################################################################################
#
#         SCRIPT DESCRIPTION: Basic Q-Learning in a single intersection
#
#         Input: Map name, route file
#         Output: Tripinfo.xml
#
#####################################################################################################

# Set MAP
used_map = 'kingsx'

# Import basic libraries
import os
import sys
import optparse
import subprocess
import random
import random
import pdb
import xmltodict
import re
import numpy as np
from __future__ import absolute_import
from __future__ import print_function

# Current working directory
working_dir = os.getcwd()

# Set environment variable SUMO_HOME
try:
    # Use this line only to manually define SUMO_HOME path
    #os.environ["SUMO_HOME"] = "/Users/acabrejasegea/sumo-0.32/"
    sys.path.append(os.path.join(os.environ['SUMO_HOME'], 'tools'))
except ImportError:
    sys.exit(
        "Please declare environment variable 'SUMO_HOME' as the root directory of your sumo installation (it should contain folders 'bin', 'tools' and 'docs')")

# Import API libraries
from sumolib import checkBinary
import traci

# %%
# %%javascript
# IPython.notebook.kernel.execute('notebook_name = "' + IPython.notebook.notebook_name + '"')

# %%
# Set important directories
networks_dir = "/Users/acabrejasegea/sumo-0.32/Data/Networks"
scripts_dir = "/Users/acabrejasegea/sumo-0.32/tools"
runners_dir = "/Users/acabrejasegea/Desktop/ATI_Project/MLforFlowOptimisation/"
notebook = (os.path.splitext(notebook_name))[0]

# %%
# Creates a route file for the simulation
def generate_routefile():
    random.seed(42)  # make tests reproducible
    N = 36000        # number of time steps
    # demand per second from different directions
    pWE = 1. / 10
    pEW = 1. / 11
    pNS = 1. / 30
    pSN = 1. / 15
    
    # Algorithmic access to routefile (names need to be consistent)
    with open(os.path.join(networks_dir, used_map, (used_map + '.rou.xml')), "w") as routes:
        print("""<routes>
        <vType id="typeWE" accel="0.8" decel="4.5" sigma="0.5" length="5" minGap="2.5" maxSpeed="16.67" guiShape="passenger"/>
        <vType id="typeNS" accel="0.8" decel="4.5" sigma="0.5" length="7" minGap="3" maxSpeed="25" guiShape="bus"/>

        <route id="right" edges="51o 1i 2o 52i" />
        <route id="left" edges="52o 2i 1o 51i" />
        <route id="down" edges="54o 4i 3o 53i" />
        <route id="up" edges="53o 3i 4o 54i" />""", file=routes)
        lastVeh = 0
        vehNr = 0
        for i in range(N):
            if random.uniform(0, 1) < pWE:
                print('    <vehicle id="right_%i" type="typeWE" route="right" depart="%i" />' % (
                    vehNr, i), file=routes)
                vehNr += 1
                lastVeh = i
            if random.uniform(0, 1) < pEW:
                print('    <vehicle id="left_%i" type="typeWE" route="left" depart="%i" />' % (
                    vehNr, i), file=routes)
                vehNr += 1
                lastVeh = i
            if random.uniform(0, 1) < pNS:
                print('    <vehicle id="down_%i" type="typeNS" route="down" depart="%i" color="1,0,0"/>' % (
                    vehNr, i), file=routes)
                vehNr += 1
                lastVeh = i
            if random.uniform(0, 1) < pSN:
                print('    <vehicle id="down_%i" type="typeNS" route="up" depart="%i" color="1,0,0"/>' % (
                    vehNr, i), file=routes)
                vehNr += 1
                lastVeh = i
        print("</routes>", file=routes)

# %%
def keywithmaxval(d):                   #Function used in Example control algorithm
     """ a) create a list of the dict's keys and values; 
         b) return the key with the max value"""  
     v=list(d.values())
     k=list(d.keys())
     return k[v.index(max(v))]

def getEdgeData(edgeIDs):
    #Edge data order (type: double / integer): [CO2, CO, Hydrocarbons, NOx, PMx, Noise,
    #mean Vehicle Length, mean Speed,occupancy, number of vehicles (integer),
    #estimated travel time, Waiting time]
    #http://sumo.dlr.de/daily/pydoc/traci._edge.html 
    data = []

    for i in range(0,len(edgeIDs)):
        data.append(traci.edge.getCO2Emission(edgeIDs[i]))
        data.append(traci.edge.getCOEmission(edgeIDs[i]))
        data.append(traci.edge.getHCEmission(edgeIDs[i]))
        data.append(traci.edge.getNOxEmission(edgeIDs[i]))
        data.append(traci.edge.getPMxEmission(edgeIDs[i]))
        data.append(traci.edge.getNoiseEmission(edgeIDs[i]))
        data.append(traci.edge.getLastStepLength(edgeIDs[i]))
        data.append(traci.edge.getLastStepMeanSpeed(edgeIDs[i]))
        data.append(traci.edge.getLastStepOccupancy(edgeIDs[i]))
        data.append(traci.edge.getLastStepVehicleNumber(edgeIDs[i]))
        data.append(traci.edge.getTraveltime(edgeIDs[i]))
        data.append(traci.edge.getWaitingTime(edgeIDs[i]))
    return data

def getInductionLoopData(inductionLoopIDs):
    #Inductive Loop data order (type: double / integer): [mean Vehicle Length,
    #mean Speed, occupancy, number of vehicles (integer)]
    #http://sumo.dlr.de/daily/pydoc/traci._inductionloop.html 
    data = []

    for i in range(0,len(inductionLoopIDs)):
        data.append(traci.inductionloop.getLastStepLength(inductionLoopIDs[i]))
        data.append(traci.inductionloop.getLastStepMeanSpeed(inductionLoopIDs[i]))
        data.append(traci.inductionloop.getLastStepOccupancy(inductionLoopIDs[i]))
        data.append(traci.inductionloop.getLastStepVehicleNumber(inductionLoopIDs[i]))
    return data

def getLaneData(laneIDs):
    #Lane data order (type: double / integer): [CO2, CO, Hydrocarbons, NOx, PMx, Noise,
    #mean Vehicle Length, mean Speed, occupancy, number of vehicles (integer),
    #estimated travel time, Waiting time]
    #http://sumo.dlr.de/daily/pydoc/traci._lane.html 
    data = []

    for i in range(0,len(laneIDs)):
        data.append(traci.lane.getCO2Emission(laneIDs[i]))
        data.append(traci.lane.getCOEmission(laneIDs[i]))
        data.append(traci.lane.getHCEmission(laneIDs[i]))
        data.append(traci.lane.getNOxEmission(laneIDs[i]))
        data.append(traci.lane.getPMxEmission(laneIDs[i]))
        data.append(traci.lane.getNoiseEmission(laneIDs[i]))
        data.append(traci.lane.getLastStepLength(laneIDs[i]))
        data.append(traci.lane.getLastStepMeanSpeed(laneIDs[i]))
        data.append(traci.lane.getLastStepOccupancy(laneIDs[i]))
        data.append(traci.lane.getLastStepVehicleNumber(laneIDs[i]))
        data.append(traci.lane.getTraveltime(laneIDs[i]))
        data.append(traci.lane.getWaitingTime(laneIDs[i]))
    return data

def getLaneAreaData(laneAreaIDs):
    #Lane area characteristic order (type: double / integer): [jam length (m), jam length (no. vehicles),
    #mean Speed, occupancy, number of vehicles (integer)]
    #http://sumo.dlr.de/daily/pydoc/traci._lanearea.html 
    data = []
    
    for i in range(0,len(laneAreaIDs)):
        data.append(traci.lanearea.getJamLengthMeters(laneAreaIDs[i]))
        data.append(traci.lanearea.getJamLengthVehicle(laneAreaIDs[i]))
        data.append(traci.lanearea.getLastStepMeanSpeed(laneAreaIDs[i]))
        data.append(traci.lanearea.getLastStepOccupancy(laneAreaIDs[i]))
        data.append(traci.lanearea.getLastStepVehicleNumber(laneAreaIDs[i]))
    return data

def getMultiEntryExitData(multiEntryExitIDs):
    #Multi entry exit detection area data order (type: double / integer):
    #mean Speed, number of vehicles (integer)]
    #http://sumo.dlr.de/daily/pydoc/traci._multientryexit.html 
    data = []

    for i in range(0,len(multiEntryExitIDs)):
        data.append(traci.multientryexit.getLastStepMeanSpeed(multiEntryExitIDs[i]))
        data.append(traci.multientryexit.getLastStepVehicleNumber(multiEntryExitIDs[i]))
    return data

def getSimulationData():
    #Simulation data order (type: double):
    #[current time, number of vehicles entering the network]
    #http://sumo.dlr.de/daily/pydoc/traci._simulation.html
    data = []

    data.append(traci.simulation.getCurrentTime())
    data.append(traci.simulation.getDepartedNumber())
    return data

def getTrafficLightData(trafficLightIDs):
    #Traffic light data = [current phase ID, phase duration,
    #current traffic phase]
    #http://sumo.dlr.de/daily/pydoc/traci._trafficlights.html 
    data = []

    for i in range(0,len(trafficLightIDs)):
        data.append(traci.trafficlights.getPhase(trafficLightIDs[i]))
        data.append(traci.trafficlights.getPhaseDuration(trafficLightIDs[i])) #this will reference the fixed time
        data.append(traci.trafficlights.getRedYellowGreenState(trafficLightIDs[i]))
    return data

def getVehicleData(vehicleIDs):
    #Individual vehicle data = [CO2, CO, Hydrocarbons, NOx, PMx, Noise,
    #emission class, total distance travelled (odometer), length,
    #list of upcoming traffic lights [(tlsID, tlsIndex, distance, state), ...], position (m,m),
    #vehicle route (edge IDs),current Speed, Vehicle Class, Waiting Time (below 0.1m/s)]
    #http://sumo.dlr.de/daily/pydoc/traci._vehicle.html 
    data = []

    for i in range(0,len(vehicleIDs)):
        data.append(traci.vehicle.getCO2Emission(vehicleIDs[i]))
        data.append(traci.vehicle.getCOEmission(vehicleIDs[i]))
        data.append(traci.vehicle.getHCEmission(vehicleIDs[i]))
        data.append(traci.vehicle.getNOxEmission(vehicleIDs[i]))
        data.append(traci.vehicle.getPMxEmission(vehicleIDs[i]))
        data.append(traci.vehicle.getNoiseEmission(vehicleIDs[i]))
        data.append(traci.vehicle.getEmissionClass(vehicleIDs[i]))
        data.append(traci.vehicle.getDistance(vehicleIDs[i]))
        data.append(traci.vehicle.getLength(vehicleIDs[i]))
        data.append(traci.vehicle.getNextTLS(vehicleIDs[i]))
        data.append(traci.vehicle.getPosition(vehicleIDs[i]))
        data.append(traci.vehicle.getRoute(vehicleIDs[i]))
        data.append(traci.vehicle.getSpeed(vehicleIDs[i]))
        data.append(traci.vehicle.getVehicleClass(vehicleIDs[i]))
        data.append(traci.vehicle.getWaitingTime(vehicleIDs[i]))
    return data

def getStaticLaneData(laneIDs):
    #Static lane data = [Lane Length, Max Speed]
    #http://sumo.dlr.de/daily/pydoc/traci._lane.html
    data = []

    #Get lane characteristics
    for i in range(0,len(laneIDs)):
        data.append(traci.lane.getLength(laneIDs[i]))
        data.append(traci.lane.getMaxSpeed(laneIDs[i]))
    return data

def getStaticTrafficLightData(trafficLightIDs):
    #Static traffic light data = [lanes controlled by traffic lights, links controlled
    #by traffic lights, ]
    #http://sumo.dlr.de/daily/pydoc/traci._trafficlights.html 
    data = []

    for i in range(0,len(trafficLightIDs)):
        data.append(traci.trafficlight.getControlledLanes(trafficLightIDs[i]))
        data.append(traci.trafficlight.getControlledLinks(trafficLightIDs[i]))
    return data

# %%
class NetworkParser:

    def __init__(self, file_path):
        self.junctions = dict()
        self.junction_lights = dict()

        with open(file_path) as f:
            self.file = xmltodict.parse(f.read())

    def get_lane_ids(self):
        for junction in self.file['net']['junction']:
            if junction['@type'] == 'traffic_light':
                self.junctions[junction['@id']] = junction['@incLanes'].split(' ')
        return self.junctions

    # Given a LaneID it returns the traffic light ID
    def get_trafficlights_by_laneID(self, laneID):
        for connection in self.file['net']['connection']:
            if connection['@from'] == laneID.split('_')[0] and '@tl' in connection:
                return connection['@tl']

    def get_junction_trafficlights(self):
        if not self.junctions:
            self.get_lane_ids()
        for junctionID in self.junctions.keys():
            for lane in self.junctions[junctionID]:
                traffic_light = self.get_trafficlights_by_laneID(lane)
                if traffic_light in self.junction_lights and lane not in self.junction_lights[traffic_light]:
                    self.junction_lights[traffic_light].append(lane)
                else:
                    self.junction_lights[traffic_light] = []
        return self.junction_lights

    def get_traffic_light(self, laneID):
        if not self.junction_lights:
            self.get_junction_trafficlights()
        for traffic_light, lanes in self.junction_lights.iteritems():
            if laneID in lanes:
                return traffic_light

    def get_phases(self, traffic_light):
        phases = []
        k=0
        for tls in self.file['net']['tlLogic']:
            if k < 1:
                #Debug stuff here
                print(tls)
                
                #End debug code
            k+=1
            if tls['@id'] == traffic_light:
                for tls_phase in tls['phase']:
                    phases.append(tls_phase)
        return phases

# %%
class Qlearner:
    def __init__(self,TLid,lanes,phases):
        self.jid     = TLid
        self.TLid    = TLid
        self.laneids = lanes
        self.Nlanes  = len(self.laneids)                                #len(nodes.junctions[self.jid])
        self.phases  = range(0, phases)                            #traci.trafficlights.getallPhases
        self.green_phases = [0, 2, 4, 6]
        num_phases = len(self.phases)
        self.Qm      = np.zeros(((2**self.Nlanes)*num_phases, num_phases))

        self.state   = 0
        self.action  = 0

    
    def set_action(self,action):
        traci.trafficlights.setPhase(self.jid, self.phases[action])

    def get_reward(self):
        return sum([traci.lane.getNOxEmission(lane_id) for lane_id in self.laneids])
 

    def get_state(self,threshold_l=3):
        current_phase = traci.trafficlights.getPhase(self.jid)
        NOXlanes=[int(traci.lane.getNOxEmission(lane_id)>threshold_l) for lane_id in self.laneids]

        state = current_phase*(2**len(NOXlanes)) + sum([x*y for x,y in zip(NOXlanes, 2**np.arange(len(NOXlanes)) )])

        return(state)

    def update(self,gamma=0.8,alpha=0.95,epsilon=0.025):
        state    = self.state
        action   = self.action
        newstate = self.get_state()
        reward   = self.get_reward()

        self.Qm[state, action] = self.Qm[state, action]*(1-alpha) + alpha*(reward + gamma*np.max(self.Qm[newstate,:]))
        
        r=np.random.rand(1)


        if r > epsilon :
            newaction = np.argmax(self.Qm[state,:])
        else:
            newaction = np.random.randint(0, len(self.phases))
        
        self.state = newstate
        self.action = newaction
        self.set_action(newaction)
        # print(newaction)

# %%
def run(learners = []):
    while traci.simulation.getMinExpectedNumber() > 0:
        traci.simulationStep()
        for learner in learners:
            learner.update()

    sys.stdout.flush()

### ORIGINAL SIMPLE CONTROLLER BELOW ###
# The program looks like this
#    <tlLogic id="0" type="static" programID="0" offset="0">
# the locations of the tls are      NESW
#        <phase duration="31" state="GrGr"/>
#        <phase duration="6"  state="yryr"/>
#        <phase duration="31" state="rGrG"/>
#        <phase duration="6"  state="ryry"/>
#    </tlLogic>
#
#def run():
#    """execute the TraCI control loop"""
#    step = 0
#    # we start with phase 2 where EW has green
#    traci.trafficlight.setPhase("0", 2)
#    while traci.simulation.getMinExpectedNumber() > 0:
#        traci.simulationStep()
#        if traci.trafficlight.getPhase("0") == 2:
#            # we are not already switching
#            if traci.inductionloop.getLastStepVehicleNumber("0") > 0:
#                # there is a vehicle from the north, switch
#                traci.trafficlight.setPhase("0", 3)
#            else:
#                # otherwise try to keep green for EW
#                traci.trafficlight.setPhase("0", 2)
#        step += 1
#    traci.close()
#    sys.stdout.flush()

# %%
def get_options():
    optParser = optparse.OptionParser()
    optParser.add_option("--nogui", action="store_true",
                         default=False, help="run the commandline version of sumo")
    options, args = optParser.parse_args()
    return options

# %%
# Deployment of Network Parser (input is network file)
npa = NetworkParser(os.path.join(networks_dir, used_map, (used_map + '.net.xml')))
nodes = npa.get_junction_trafficlights()

# %%
t=0
for k in npa.get_junction_trafficlights().keys():
    if t<1:
        print(k)
    t+=1
npa.get_phases('GS_107867')
# Out:
# GS_107867
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrGGGggrrrr')]),
#  OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrryyyggrrrr')]),
#  OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrGGrrrr')]),
#  OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrryyrrrr')]),
#  OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGggrrrrrGGgg')]),
#  OrderedDict([('@duration', '2'), ('@state', 'rrrrryyggrrrrryygg')]),
#  OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrGGrrrrrrrGG')]),
#  OrderedDict([('@duration', '2'), ('@state', 'rrrrrrryyrrrrrrryy')])]

# %%
for tls in npa.file['net']['tlLogic']:
    print(tls)
# Out:
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '1232377095'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '86'), ('@state', 'GG')]), OrderedDict([('@duration', '4'), ('@state', 'yy')])])])
# OrderedDict([('@id', '1365141255'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '88'), ('@state', 'GG')]), OrderedDict([('@duration', '2'), ('@state', 'yy')])])])
# OrderedDict([('@id', '1448819964'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '88'), ('@state', 'GGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyy')])])])
# OrderedDict([('@id', '234290'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '31'), ('@state', 'GGGggrrrrGGGgrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyggrrrryyygrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrryyrrrrrrryrrrr')]), OrderedDict([('@duration', '31'), ('@state', 'rrrrrGGggrrrrGGgg')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrryyggrrrryygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrGGrrrrrrGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrrrryyrrrrrryy')])])])
# OrderedDict([('@id', '2440661715'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '86'), ('@state', 'GG')]), OrderedDict([('@duration', '4'), ('@state', 'yy')])])])
# OrderedDict([('@id', '25508636'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '36'), ('@state', 'GgGgGGggrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyygyyggrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGrrGGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrryrryyrrrr')]), OrderedDict([('@duration', '36'), ('@state', 'rGrrrrrrGGGg')]), OrderedDict([('@duration', '4'), ('@state', 'ryrrrrrryyyy')])])])
# OrderedDict([('@id', '25508642'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'rrrrGGggrrrrGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrryyggrrrryygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrGGrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrryyrrrrrryy')]), OrderedDict([('@duration', '35'), ('@state', 'GGggrrrrGGggrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyggrrrryyggrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrGGrrrrrrGGrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rryyrrrrrryyrrrr')])])])
# OrderedDict([('@id', '26242765'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '36'), ('@state', 'GGGgrrrrGGgg')]), OrderedDict([('@duration', '4'), ('@state', 'yyygrrrryygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGrrrrrrGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrryrrrrrryy')]), OrderedDict([('@duration', '36'), ('@state', 'rrrrGGGGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrrryyyyrrrr')])])])
# OrderedDict([('@id', '3310091781'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '88'), ('@state', 'GG')]), OrderedDict([('@duration', '2'), ('@state', 'yy')])])])
# OrderedDict([('@id', '820870'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '36'), ('@state', 'ggGGrr')]), OrderedDict([('@duration', '4'), ('@state', 'ggyyrr')]), OrderedDict([('@duration', '6'), ('@state', 'GGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyrrrr')]), OrderedDict([('@duration', '36'), ('@state', 'rrrrGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrrryy')])])])
# OrderedDict([('@id', '874743581'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '86'), ('@state', 'GGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyy')])])])
# OrderedDict([('@id', 'GS_107867'), ('@type', 'static'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrGGGggrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrryyyggrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrGGrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrryyrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGggrrrrrGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyggrrrrryygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrGGrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrryyrrrrrrryy')])])])
# OrderedDict([('@id', 'GS_108040'), ('@type', 'static'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '43'), ('@state', 'GGGrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyrrr')]), OrderedDict([('@duration', '43'), ('@state', 'rrrGGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyy')])])])
# OrderedDict([('@id', 'GS_25495406'), ('@type', 'static'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '41'), ('@state', 'gG')]), OrderedDict([('@duration', '4'), ('@state', 'yy')]), OrderedDict([('@duration', '41'), ('@state', 'rG')]), OrderedDict([('@duration', '4'), ('@state', 'ry')])])])
# OrderedDict([('@id', 'GS_775618529'), ('@type', 'static'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '41'), ('@state', 'GgGrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyrr')]), OrderedDict([('@duration', '41'), ('@state', 'rrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'rryyy')])])])
# OrderedDict([('@id', 'GS_821559'), ('@type', 'static'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '41'), ('@state', 'GGgGGr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyr')]), OrderedDict([('@duration', '41'), ('@state', 'rrrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrryyy')])])])
# OrderedDict([('@id', 'cluster_10365738_1519252876_1519252880_1573841958_2470352828_2470352831_2532429826_25472381'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '36'), ('@state', 'GGGggrrrrGGGGg')]), OrderedDict([('@duration', '4'), ('@state', 'yyyggrrrryyyyg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrG')]), OrderedDict([('@duration', '4'), ('@state', 'rrryyrrrrrrrry')]), OrderedDict([('@duration', '36'), ('@state', 'rrrrrGGGgGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrryyyyyrrrr')])])])
# OrderedDict([('@id', 'cluster_10703277_1684437713_2362119846'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '88'), ('@state', 'GGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyy')])])])
# OrderedDict([('@id', 'cluster_10703451_1680837220_5286903651_5286903654_5286903660'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '80'), ('@state', 'GGggGGGg')]), OrderedDict([('@duration', '2'), ('@state', 'yyggyyyg')]), OrderedDict([('@duration', '6'), ('@state', 'rrGGrrrG')]), OrderedDict([('@duration', '2'), ('@state', 'rryyrrry')])])])
# OrderedDict([('@id', 'cluster_107865_4360469329_4360486826'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '88'), ('@state', 'GGg')]), OrderedDict([('@duration', '2'), ('@state', 'yyy')])])])
# OrderedDict([('@id', 'cluster_107974_5327975831_5327977753_5435961188'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '36'), ('@state', 'GgGggrrr')]), OrderedDict([('@duration', '4'), ('@state', 'ygyggrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rGrGGrrr')]), OrderedDict([('@duration', '4'), ('@state', 'ryryyrrr')]), OrderedDict([('@duration', '36'), ('@state', 'rrrrrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrryyy')])])])
# OrderedDict([('@id', 'cluster_108034_1448876379_3645264139'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '39'), ('@state', 'GgggGGGGGgrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'ygggyyyyygrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rGGGrrrrrGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'ryyyrrrrryrrrrr')]), OrderedDict([('@duration', '39'), ('@state', 'GrrrrrrrrrGGGGg')]), OrderedDict([('@duration', '2'), ('@state', 'yrrrrrrrrryyyyy')])])])
# OrderedDict([('@id', 'cluster_110094_294659411_294659416'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '31'), ('@state', 'GGGggrrrrGGGggrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyggrrrryyyggrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrGGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrryyrrrrrrryyrrrr')]), OrderedDict([('@duration', '31'), ('@state', 'rrrrrGGggrrrrrGGgg')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrryyggrrrrryygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrGGrrrrrrrGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrrrryyrrrrrrryy')])])])
# OrderedDict([('@id', 'cluster_110099_14958919_3215065353_3215065355_3215065356_3215065358'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '31'), ('@state', 'rrrrGGGGggrrrrGGGgg')]), OrderedDict([('@duration', '4'), ('@state', 'rrrryyyyggrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrrrrryyrrrrrrryy')]), OrderedDict([('@duration', '31'), ('@state', 'GGggrrrrrrGGggrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyggrrrrrryyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rryyrrrrrrrryyrrrrr')])])])
# OrderedDict([('@id', 'cluster_1651797157_1685938692_2414118569_2414118571_2414118572_25522558_25522559_25522560_5607749657_821550'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '36'), ('@state', 'ggggrrrrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'ggggrrrryyy')]), OrderedDict([('@duration', '6'), ('@state', 'GGGGrrrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyrrrrrrr')]), OrderedDict([('@duration', '36'), ('@state', 'rrrrGGGgGrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrrryyyyyrr')])])])
# OrderedDict([('@id', 'cluster_242401771_29740919'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '43'), ('@state', 'GGGGGGrrG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyyrry')]), OrderedDict([('@duration', '43'), ('@state', 'GrrrGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yrrryyyyy')])])])
# OrderedDict([('@id', 'cluster_265111477_294158420'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrGGGggrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrryyyggrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrGGrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrryyrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGggrrrrrGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyggrrrrryygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrGGrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrryyrrrrrrryy')])])])
# OrderedDict([('@id', 'cluster_291720942_823943'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '36'), ('@state', 'rrggGGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrggyyy')]), OrderedDict([('@duration', '6'), ('@state', 'rrGGrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rryyrrr')]), OrderedDict([('@duration', '36'), ('@state', 'GgGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyrrrr')])])])
# OrderedDict([('@id', 'joinedS_0'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '86'), ('@state', 'GGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyy')])])])
# OrderedDict([('@id', 'joinedS_1'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '43'), ('@state', 'GGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyy')]), OrderedDict([('@duration', '43'), ('@state', 'GGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyy')])])])
# OrderedDict([('@id', 'joinedS_10'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '26'), ('@state', 'GGGGGrrGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyrryyyy')]), OrderedDict([('@duration', '26'), ('@state', 'GGGrrGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyrryyyyyy')]), OrderedDict([('@duration', '26'), ('@state', 'GGGGGrrGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyrryyyy')])])])
# OrderedDict([('@id', 'joinedS_11'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '86'), ('@state', 'GGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyy')])])])
# OrderedDict([('@id', 'joinedS_12'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '26'), ('@state', 'rrrrrGGGGGrrrrGGGGGGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrryyyyyrrrryyyyyyyyyyy')]), OrderedDict([('@duration', '26'), ('@state', 'GGrGGrrrGGrGGgGGGrrrGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyryyrrryyryyyyyyrrryyyyy')]), OrderedDict([('@duration', '26'), ('@state', 'GGgGGrrrGGgGGrGGGrrrGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyrrryyyyyryyyrrryyyyy')])])])
# OrderedDict([('@id', 'joinedS_13'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '16'), ('@state', 'GGgGrGgGrGGgGgG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyryyyryyyyyy')]), OrderedDict([('@duration', '16'), ('@state', 'GGgGrGgGgGGgGrG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyryyyyyyyyry')]), OrderedDict([('@duration', '16'), ('@state', 'GGgGrGgGrGGgGrG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyryyyryyyyry')]), OrderedDict([('@duration', '16'), ('@state', 'GGrGgGgGrGGgGrG')]), OrderedDict([('@duration', '2'), ('@state', 'yyryyyyyryyyyry')]), OrderedDict([('@duration', '16'), ('@state', 'GGgGrGgGrGGgGrG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyryyyryyyyry')])])])
# OrderedDict([('@id', 'joinedS_14'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '19'), ('@state', 'GgGrGGgGGrGGgGGgGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyryyyyyryyyyyyyy')]), OrderedDict([('@duration', '21'), ('@state', 'GgGrGGgGGgGGgGGrGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyryyyyyyyyyyyryy')]), OrderedDict([('@duration', '21'), ('@state', 'GgGrGGgGGrGGgGGrGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyryyyyyryyyyyryy')]), OrderedDict([('@duration', '21'), ('@state', 'GrGgGGgGGrGGgGGrGG')]), OrderedDict([('@duration', '2'), ('@state', 'yryyyyyyyryyyyyryy')])])])
# OrderedDict([('@id', 'joinedS_15'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '41'), ('@state', 'GrGGGgGGGgGr')]), OrderedDict([('@duration', '4'), ('@state', 'yryyyyyyyyyr')]), OrderedDict([('@duration', '41'), ('@state', 'GgGGGrGGGrGg')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyryyyryy')])])])
# OrderedDict([('@id', 'joinedS_16'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '41'), ('@state', 'GGGGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyy')]), OrderedDict([('@duration', '41'), ('@state', 'GGGGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyy')])])])
# OrderedDict([('@id', 'joinedS_17'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '28'), ('@state', 'GGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyy')]), OrderedDict([('@duration', '28'), ('@state', 'GGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyy')]), OrderedDict([('@duration', '28'), ('@state', 'GGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyy')])])])
# OrderedDict([('@id', 'joinedS_18'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '43'), ('@state', 'GGGGGrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyrrr')]), OrderedDict([('@duration', '43'), ('@state', 'GrrrrGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yrrrryyy')])])])
# OrderedDict([('@id', 'joinedS_19'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '41'), ('@state', 'GGGrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyryyy')]), OrderedDict([('@duration', '41'), ('@state', 'GGGgGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyy')])])])
# OrderedDict([('@id', 'joinedS_2'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '28'), ('@state', 'GGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyy')]), OrderedDict([('@duration', '28'), ('@state', 'GGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyy')]), OrderedDict([('@duration', '28'), ('@state', 'GGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyy')])])])
# OrderedDict([('@id', 'joinedS_20'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '31'), ('@state', 'GGGGGGrrrrGGGGggrrrrGGGGgg')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyrrrryyyyggrrrryyyygg')]), OrderedDict([('@duration', '6'), ('@state', 'GGGrrrrrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyrrrrrrrrrrryyrrrrrrrryy')]), OrderedDict([('@duration', '31'), ('@state', 'GGGrrrGGggrrrrrrGGggrrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyrrryyggrrrrrryyggrrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'GGGrrrrrGGrrrrrrrrGGrrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyrrrrryyrrrrrrrryyrrrrrr')])])])
# OrderedDict([('@id', 'joinedS_21'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '11'), ('@state', 'GGGGGGGGGGgGGGrGGGgGrGGGgGr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyryyyyyryyyyyr')]), OrderedDict([('@duration', '11'), ('@state', 'GGGGGGGGGGrGGGgGGGgGrGGGgGr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyryyyyyyyyyryyyyyr')]), OrderedDict([('@duration', '11'), ('@state', 'GGGGGGGGGGgGGGrGGGgGrGGGgGr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyryyyyyryyyyyr')]), OrderedDict([('@duration', '11'), ('@state', 'GGGGGGGGGGgGGGrGGGgGrGGGrGg')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyryyyyyryyyryy')]), OrderedDict([('@duration', '11'), ('@state', 'GGGGGGGGGGgGGGrGGGrGgGGGgGr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyryyyryyyyyyyr')]), OrderedDict([('@duration', '11'), ('@state', 'GGGGGGGGGGgGGGrGGGgGrGGGgGr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyryyyyyryyyyyr')])])])
# OrderedDict([('@id', 'joinedS_22'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '16'), ('@state', 'GGGgGrGrGGGgGGgGrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyryryyyyyyyyrrrrr')]), OrderedDict([('@duration', '16'), ('@state', 'GGGgGrGgGGGrGGgGggrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyygyrygyyyryygyggrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGrrrGrrrrrrGrGGrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrryrrryrrrrrryryyrrr')]), OrderedDict([('@duration', '16'), ('@state', 'GGGrGgGgGGGrGGgGrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyryyyyyyyryyyyrrrrr')]), OrderedDict([('@duration', '16'), ('@state', 'GGGgGrGgGGGrGrrrrrGGg')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyryyyyyryrrrrryyy')])])])
# OrderedDict([('@id', 'joinedS_23'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '86'), ('@state', 'GGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyy')])])])
# OrderedDict([('@id', 'joinedS_24'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '31'), ('@state', 'GGGGGggrrrrGGggrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyggrrrryyggrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrGGrrrrrrGGrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrryyrrrrrryyrrrr')]), OrderedDict([('@duration', '31'), ('@state', 'rrrrrrrGGggrrrrGGgg')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrrrryyggrrrryygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrrGGrrrrrrGG')]), OrderedDict([('@duration', '4'), ('@state', 'rrrrrrrrryyrrrrrryy')])])])
# OrderedDict([('@id', 'joinedS_25'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '17'), ('@state', 'GGGGGGGGGGGGGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyyyyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGGGGGGGGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyyyyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGGGGGGGGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyyyyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGGGGGGGGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyyyyyyyy')])])])
# OrderedDict([('@id', 'joinedS_3'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '76'), ('@state', 'GGGGgggGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyygggyyyyyy')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrGGGrrrrrr')]), OrderedDict([('@duration', '4'), ('@state', 'rrrryyyrrrrrr')])])])
# OrderedDict([('@id', 'joinedS_4'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '80'), ('@state', 'GGGggGGGGGGGGgggGGGGgggggGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggyyyyyyyygggyyyygggggyyy')]), OrderedDict([('@duration', '6'), ('@state', 'GGrggGGrrrGGGGGgrrrrGggGGrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyryyyyrrryyyyyyrrrryyyyyrrr')])])])
# OrderedDict([('@id', 'joinedS_5'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '17'), ('@state', 'GGGGGGGGGgGrGGGGrGGGGgGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyryyyyryyyyyyyyyyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGGGGgGrGGGGgGGGGrGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyryyyyyyyyyryyyyyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGGGGrGgGGGGgGGGGrGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyryyyyyyyyyyyryyyyyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGGGGgGrGGGGgGGGGrGGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyyryyyyyyyyyryyyyyy')])])])
# OrderedDict([('@id', 'joinedS_6'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '17'), ('@state', 'GGGGGGrGGGgGGGgGrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyryyyyyyyyyryyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGgGGGrGGGgGrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyryyyyyryyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGgGGGrGGGgGrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyryyyyyryyy')]), OrderedDict([('@duration', '19'), ('@state', 'GGGGGGgGGGrGGGrGgGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyyyyyyryyyryyyyy')])])])
# OrderedDict([('@id', 'joinedS_7'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '16'), ('@state', 'GGGgGrGGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyryyyyyy')]), OrderedDict([('@duration', '16'), ('@state', 'GGGgGrGGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyryyyyyy')]), OrderedDict([('@duration', '16'), ('@state', 'GGGgGgGGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyyyyyyyy')]), OrderedDict([('@duration', '16'), ('@state', 'GGGgGrGGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyryyyyyy')]), OrderedDict([('@duration', '16'), ('@state', 'GGGgGrGGGGGG')]), OrderedDict([('@duration', '2'), ('@state', 'yyyyyryyyyyy')])])])
# OrderedDict([('@id', 'joinedS_8'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '86'), ('@state', 'GGGGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyyy')])])])
# OrderedDict([('@id', 'joinedS_9'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '18'), ('@state', 'GGggrrrrGGGggrGGGrGGGgGGg')]), OrderedDict([('@duration', '4'), ('@state', 'yyggrrrryyyggryyyryyygyyg')]), OrderedDict([('@duration', '6'), ('@state', 'GGGGrrrrrrrggrrGGrrrrgGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyrrrrrrryyrryyrrrryyyy')]), OrderedDict([('@duration', '20'), ('@state', 'GGGgGgggrrrrrgGGGrrrrrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyygygggrrrrrgyyyrrrrryyy')]), OrderedDict([('@duration', '6'), ('@state', 'GGGGrgggrrrrrgrGGrrrrrGGG')]), OrderedDict([('@duration', '4'), ('@state', 'yyyyryyyrrrrryryyrrrrryyy')]), OrderedDict([('@duration', '20'), ('@state', 'rGGgGrrrrrrrrGrrrGgGGrGGr')]), OrderedDict([('@duration', '4'), ('@state', 'ryyyyrrrrrrrryrrryyyyryyr')])])])

# %%
phase_list = [len(npa.get_phases(k)) for k in npa.get_junction_trafficlights().keys()]
# Out:
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])
# OrderedDict([('@id', '108909'), ('@type', 'actuated'), ('@programID', '0'), ('@offset', '0'), ('phase', [OrderedDict([('@duration', '35'), ('@state', 'GGGggrrrrrGGGggrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'yyyggrrrrryyyggrrrrr')]), OrderedDict([('@duration', '6'), ('@state', 'rrrGGrrrrrrrrGGrrrrr')]), OrderedDict([('@duration', '2'), ('@state', 'rrryyrrrrrrrryyrrrrr')]), OrderedDict([('@duration', '35'), ('@state', 'rrrrrGGGggrrrrrGGGgg')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrryyyggrrrrryyygg')]), OrderedDict([('@duration', '6'), ('@state', 'rrrrrrrrGGrrrrrrrrGG')]), OrderedDict([('@duration', '2'), ('@state', 'rrrrrrrryyrrrrrrrryy')])])])

# %%
sumoBinary = checkBinary('sumo-gui')
# OR
# sumoBinary = checkBinary('sumo')

# %%
generate_routefile()

# %%
traci.start([sumoBinary, "-c", os.path.join(networks_dir, used_map, (used_map + '.sumocfg')),
                             "--tripinfo-output", os.path.join((notebook + '_out'), 'tripinfo.xml')])
# Out:
# Could not connect to TraCI server at localhost:52600 [Errno 61] Connection refused
#  Retrying in 1 seconds
# ---------------------------------------------------------------------------
# FatalTraCIError                           Traceback (most recent call last)
# <ipython-input-15-16831c2ded09> in <module>()
#       1 traci.start([sumoBinary, "-c", os.path.join(networks_dir, used_map, (used_map + '.sumocfg')),
# ----> 2                              "--tripinfo-output", os.path.join((notebook + '_out'), 'tripinfo.xml')])
#
# ~/sumo-0.32/tools/traci/__init__.py in start(cmd, port, numRetries, label)
#      83     _connections[label] = connect(port, numRetries, "localhost", sumoProcess)
#      84     switch(label)
# ---> 85     return getVersion()
#      86
#      87
#
# ~/sumo-0.32/tools/traci/__init__.py in getVersion()
#     155
#     156 def getVersion():
# --> 157     return _connections[""].getVersion()
#     158
#     159
#
# ~/sumo-0.32/tools/traci/connection.py in getVersion(self)
#     287         self._queue.append(command)
#     288         self._string += struct.pack("!BB", 1 + 1, command)
# --> 289         result = self._sendExact()
#     290         result.readLength()
#     291         response = result.read("!B")[0]
#
# ~/sumo-0.32/tools/traci/connection.py in _sendExact(self)
#      95             self._socket.close()
#      96             del self._socket
# ---> 97             raise FatalTraCIError("connection closed by SUMO")
#      98         for command in self._queue:
#      99             prefix = result.read("!BBB")
#
# FatalTraCIError: connection closed by SUMO

# %%
run()
