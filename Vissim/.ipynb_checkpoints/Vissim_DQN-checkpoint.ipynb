# %%
## VISSIM Modules
import win32com.client as com
import os

## RL Modules
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("ERROR: GPU DEVICE NOT FOUND.")

from keras.models import load_model
    
## Data Management Modules
import pickle

## User Defined Modules
import Simulator_Functions as SF
from RLAgents import DQNAgent
from NParser import NetworkParser
from COMServer import COMServerDispatch, COMServerReload
from TupleToList import toList
from Utilities import log_progress, pltlive
## Other Modules
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Default GPU Device: /device:GPU:0
# Using TensorFlow backend.

# %%
## Network Model Parameters
Random_Seed = 42
model_name  = 'Single_Cross_Straight'
vissim_working_directory = 'C:\\Users\\acabrejasegea\\OneDrive - The Alan Turing Institute\\Desktop\\ATI\\0_TMF\\MLforFlowOptimisation\\Vissim\\'
program = 'DQN' # DQN, DuelingDQN, DDQN, DuelingDDQN
reward_type = 'Queues'
state_type  = 'Queues'
PER_activated = True
## Use of additional files?
flag_read_additionally  = False
## Load trained model?
Demo_Mode = False
load_trained = False
Quickmode = True
SaveResultsAgent = True
# Random demand
Random_Demand = False

# %%
## Data handling flags
# Flag for restarting the COM Server
reset_flag = True
#cache_flag = False
# If a fresh start is needed, all previous results from simulations are deleted
Start_Fresh = True
# Debug action
debug_action = False

# %%
## RL Hyperparamenters
# Number of simulations, save every "n" episodes and copy weights with frequency "f"
episodes = 400
partial_save_at = 100
copy_weights_frequency = 5
reset_frequency = 100

# Timesteps per simulation (1 timestep = 0.1 sec), length for random population is a multiple of episode
simulation_length = 3600*1 + 1
memory_population_length = simulation_length*5

## State-Action Parameters
state_size = 4
action_size = 5

# Hyperparameters
batch_size = 64
memory_size = 1000
alpha   = 0.0001
#alpha   = 0.001

gamma   = 0.95

# Exploration Schedule
epsilon_start = 1
epsilon_end   = 0.001
epsilon_decay = 1.2*(epsilon_end - epsilon_start)/(episodes-1)
#epsilon_decay = np.power(epsilon_end/epsilon_start, 1./(episodes+1)) # Geometric decay

# Demand Schedule
demands = [100, 200, 400, 600, 800, 1000]
# Session ID
Session_ID = 'Episodes'+str(episodes)+'_Program'+program

# %%
if __name__ == "__main__":
    # Initialize storage
    reward_storage = []
    best_agent_weights = []
    reward_plot = np.zeros([episodes,])
    loss_plot = np.zeros([episodes,])

    # If previous agents aren't to be loaded, proceed to memory population
    if not load_trained:
        # Initialize simulation
        if 'Vissim' not in globals() or Vissim == None:
            Vissim, Simulation, Network, cache_flag = COMServerDispatch(model_name, vissim_working_directory,\
                                                                        memory_population_length, Start_Fresh,\
                                                                        reset_flag = True, verbose = True)
        else:
            Vissim = com.Dispatch("Vissim.Vissim")
            Simulation, Network = COMServerReload(Vissim, model_name, vissim_working_directory,\
                                                  memory_population_length, Start_Fresh, reset_flag = True)
        
    # Setting Random Seed
    Vissim.Simulation.SetAttValue('RandSeed', Random_Seed)
    print ('Random seed set in simulator. Random Seed = '+str(Random_Seed))
    Vissim.Simulation.SetAttValue('SimRes', 1)


    # Deploy Network Parser (crawl network)
    npa = NetworkParser(Vissim)
    print('NetworkParser has succesfully crawled the model network.')
    
    # Initialize agents
    if program == "DQN":
        Agents = [DQNAgent(state_size, action_size, ID, state_type, npa, memory_size, gamma, 0 if Demo_Mode else epsilon_start,\
                           epsilon_end, epsilon_decay, alpha, copy_weights_frequency, Vissim, PER_activated, DoubleDQN = False,\
                           Dueling = False) for ID in npa.signal_controllers_ids] 
        agents_deployed = True
    elif program == "DuelingDQN":
        Agents = [DQNAgent(state_size, action_size, ID, state_type, npa, memory_size, gamma, 0 if Demo_Mode else epsilon_start,\
                           epsilon_end, epsilon_decay, alpha, copy_weights_frequency, Vissim, PER_activated, DoubleDQN = False,\
                           Dueling = True) for ID in npa.signal_controllers_ids] 
        agents_deployed = True
    elif program == "DDQN":
        Agents = [DQNAgent(state_size, action_size, ID, state_type, npa, memory_size, gamma, 0 if Demo_Mode else epsilon_start,\
                           epsilon_end, epsilon_decay, alpha, copy_weights_frequency, Vissim, PER_activated, DoubleDQN = True,\
                           Dueling = False) for ID in npa.signal_controllers_ids] 
        agents_deployed = True
    elif program == "DuelingDDQN":
        Agents = [DQNAgent(state_size, action_size, ID, state_type, npa, memory_size, gamma, 0 if Demo_Mode else epsilon_start,\
                           epsilon_end, epsilon_decay, alpha, copy_weights_frequency, Vissim, PER_activated, DoubleDQN = True,\
                           Dueling = True) for ID in npa.signal_controllers_ids] 
        agents_deployed = True
    else:
        print("Incorrect Agent Class selected. Deployment could not be completed.")
        quit()
    
    if agents_deployed:
        print("Deployed {} agent(s) of the Class {}.".format(len(Agents), program))
    
    if Demo_Mode:
        Agents = SF.load_agents(vissim_working_directory, model_name, Agents, Session_ID, best = True)
        SF.run_simulation_episode(Agents, Vissim, state_type, state_size, memory_population_length, Demo_Mode, PER_activated)
        Vissim = None
    # Load previous trained data
    elif load_trained:
        Agents = SF.load_agents(vissim_working_directory, model_name, Agents, Session_ID, best = False)
    # If previous data isn't to be loaded, have an initial longer random run to populate memory
    else:
        print('Pre-Populating memory with Random Actions....')
        SF.Set_Quickmode(Vissim)
        if PER_activated:
            memory = SF.PER_prepopulate_memory(Agents, Vissim, state_type, state_size, memory_size, vissim_working_directory, model_name)
        else:
            SF.run_simulation_episode(Agents, Vissim, state_type, state_size, memory_population_length, Demo_Mode, PER_activated)
        print('Memory pre-populated. Starting Training.\n')
        
    # Iterations of the simulation
    for episode in log_progress(range(episodes), every=1):
        
#        # Starting Plotting Backend
#        if episode == 0:
#            # Start reward plot
#            rew,axr = plt.subplots(1,1)
#            axr.set_xlabel('Episodes')
#            axr.set_ylabel('Average agent reward in episode')
#            axr.set_xlim(0,episodes)
#            axr.set_ylim(-500,0)
#            # Start loss plot
#            loss,axl = plt.subplots(1,1)
#            axl.set_xlabel('Episodes')
#            axl.set_ylabel('Average agent loss')
#            axl.set_xlim(0,episodes)
#            axl.set_ylim(0,2000000)
#            pltlive(reward_plot, episodes, rew, axr, ['r'])
#            pltlive(loss_plot, episodes, loss, axl, ['b'])
#        else:
#            reward_plot[episode] = reward_storage[-1]
#            loss_plot[episode] = Agents[0].loss[-1][0]
#
#            pltlive(reward_plot, episodes, rew, axr, ['r'])
#            pltlive(loss_plot, episodes, loss, axl, ['b'])
        
        # Completely re-dispatch server every N iterations for performance
        if episode % reset_frequency == 0 and episode !=0:
            Vissim = None
            Vissim, Simulation, Network, cache_flag = COMServerDispatch(model_name, vissim_working_directory,\
                                                                        simulation_length, Start_Fresh,\
                                                                        reset_flag = True, verbose = False)
            print("Redispatched")
        else:
            # If not the first episode, reset state at the start
            Simulation, Network = COMServerReload(Vissim, model_name, vissim_working_directory,\
                                                simulation_length, Start_Fresh, reset_flag = True)
        
        # Run Network Parser and ensure agents are linked to their intersections
        npa = NetworkParser(Vissim) 
        for index, agent in enumerate(Agents):
            agent.update_IDS(npa.signal_controllers_ids[index], npa)
            agent.episode_reward = []
        
        # Change demand for every episode
        if Random_Demand:
            for vehicle_input in range(1,5):
                Vissim.Net.VehicleInputs.ItemByKey(vehicle_input).SetAttValue('Volume(1)', demands[np.random.randint(0,len(demands)-1)])    
        
        # Change the random seed
        Random_Seed += 1
        Vissim.Simulation.SetAttValue('RandSeed', Random_Seed)
        
        # Run Episode at maximum speed
        SF.Set_Quickmode(Vissim)
        SF.run_simulation_episode(Agents, Vissim, state_type, state_size, simulation_length, Demo_Mode, PER_activated)
        
        # Calculate episode average reward
        reward_storage, average_reward = SF.average_reward(reward_storage, Agents, episode, episodes)
        best_agent_weights = SF.best_agent(reward_storage, average_reward, best_agent_weights, vissim_working_directory, model_name, Agents, Session_ID)
        
        # Train agent with experience of episode (indicated batch size)
        for agent in Agents:
            agent.replay_batch(batch_size, episode)
            #break
        # Security save for long trainings
        if SaveResultsAgent:
            if (episode+1)%partial_save_at == 0:
                SF.save_agents(vissim_working_directory, model_name, Agents, Session_ID, reward_storage)
                print('Saved Partial results at the end of episode {}.'.format(episode+1))

    #Saving agents memory, weights and optimizer
    if SaveResultsAgent:
        SF.save_agents(vissim_working_directory, model_name, Agents, Session_ID, reward_storage)
        print("Model, architecture, weights, optimizer, memory and training results succesfully saved. Succesfully Terminated.")
    
    # Close Vissim
    Vissim = None
# Out:
# Working Directory set to: C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\
# Generating Cache...
# Cache generated.
#
# ****************************
# *   COM Server dispatched  *
# ****************************
#
# Loading Model File: Single_Cross_Straight.inpx ...
# Load process successful
# Simulation length set to 1800.5 seconds.
# Results from Previous Simulations: Deleted. Fresh Start Available.
# Fetched and containerized Simulation Object
# Fetched and containerized Network Object
#
# *******************************************************
# *                                                     *
# *                 SETUP COMPLETE                      *
# *                                                     *
# *******************************************************
#
# Random seed set in simulator. Random Seed = 42
# NetworkParser has succesfully crawled the model network.
# WARNING:tensorflow:From C:\Users\acabrejasegea\AppData\Local\Continuum\anaconda3\envs\vissimgpu\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Deploying instance of Dueling Double Deep Q Learning Agent(s)
# Deployed 1 agent(s) of the Class DuelingDDQN.
# Pre-Populating memory with Random Actions....
# Previous Experience Found
# Memory pre-populated. Starting Training.
# VBox(children=(HTML(value=''), IntProgress(value=0, max=400)))
# Episode: 1/400, Epsilon:1, Average reward: -199.71
# Prediction for [500,0,500,0] is: [[-138.8951   -191.27602   -24.244865  -91.2652    -93.41421 ]]
# New best agent found. Saved in C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\Single_Cross_Straight\Single_Cross_Straight_Episodes400_ProgramDuelingDDQN_BestAgent0_Memory.p
# WARNING:tensorflow:From C:\Users\acabrejasegea\AppData\Local\Continuum\anaconda3\envs\vissimgpu\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Episode: 2/400, Epsilon:1.0, Average reward: -126.19
# Prediction for [500,0,500,0] is: [[-140.47687  -192.76219   -27.882523  -93.00787   -95.010895]]
# New best agent found. Saved in C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\Single_Cross_Straight\Single_Cross_Straight_Episodes400_ProgramDuelingDDQN_BestAgent0_Memory.p
# Episode: 3/400, Epsilon:0.99, Average reward: -355.18
# Prediction for [500,0,500,0] is: [[-142.0021   -194.04674   -31.27372   -94.721664  -97.09293 ]]
# Episode: 4/400, Epsilon:0.99, Average reward: -326.61
# Prediction for [500,0,500,0] is: [[-143.34354  -195.08379   -33.989037  -97.226906  -99.427475]]
# Episode: 5/400, Epsilon:0.99, Average reward: -226.14
# Prediction for [500,0,500,0] is: [[-144.65785 -196.22859  -36.51201  -99.93988 -101.61606]]
# Weights succesfully copied to Target model.
# Episode: 6/400, Epsilon:0.98, Average reward: -53.69
# Prediction for [500,0,500,0] is: [[-145.94409  -197.37735   -38.769386 -102.6132   -104.07063 ]]
# New best agent found. Saved in C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\Single_Cross_Straight\Single_Cross_Straight_Episodes400_ProgramDuelingDDQN_BestAgent0_Memory.p
# Episode: 7/400, Epsilon:0.98, Average reward: -207.37
# Prediction for [500,0,500,0] is: [[-147.28943 -198.57185  -41.1075  -105.06708 -106.58536]]
# Episode: 8/400, Epsilon:0.98, Average reward: -285.75
# Prediction for [500,0,500,0] is: [[-148.6625  -199.74231  -43.47151 -107.55001 -108.93237]]
# Episode: 9/400, Epsilon:0.98, Average reward: -36.76
# Prediction for [500,0,500,0] is: [[-149.93903  -201.12888   -45.785408 -110.05533  -111.30937 ]]
# New best agent found. Saved in C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\Single_Cross_Straight\Single_Cross_Straight_Episodes400_ProgramDuelingDDQN_BestAgent0_Memory.p
# Episode: 10/400, Epsilon:0.97, Average reward: -203.67
# Prediction for [500,0,500,0] is: [[-151.12398  -202.54007   -48.031868 -112.66934  -113.72911 ]]
# Weights succesfully copied to Target model.
# Episode: 11/400, Epsilon:0.97, Average reward: -368.58
# Prediction for [500,0,500,0] is: [[-152.29688  -203.94527   -50.213272 -115.51145  -116.09278 ]]
# Episode: 12/400, Epsilon:0.97, Average reward: -280.49
# Prediction for [500,0,500,0] is: [[-153.51259  -205.31824   -52.631065 -118.28605  -118.37265 ]]
# Episode: 13/400, Epsilon:0.96, Average reward: -204.27
# Prediction for [500,0,500,0] is: [[-154.89856  -206.59586   -55.004585 -120.985115 -120.884415]]
# Episode: 14/400, Epsilon:0.96, Average reward: -189.49
# Prediction for [500,0,500,0] is: [[-156.26079 -207.89627  -57.11479 -123.93362 -123.54874]]
# Episode: 15/400, Epsilon:0.96, Average reward: -64.54
# Prediction for [500,0,500,0] is: [[-157.52585  -209.23582   -59.08937  -126.82395  -126.205925]]
# Weights succesfully copied to Target model.
# Episode: 16/400, Epsilon:0.95, Average reward: -373.85
# Prediction for [500,0,500,0] is: [[-158.94998 -210.62814  -61.09822 -129.49539 -128.70528]]
# Episode: 17/400, Epsilon:0.95, Average reward: -419.6
# Prediction for [500,0,500,0] is: [[-160.383   -212.03485  -63.19227 -132.16092 -131.23004]]
# Episode: 18/400, Epsilon:0.95, Average reward: -217.15
# Prediction for [500,0,500,0] is: [[-161.67311  -213.56842   -65.412735 -134.76013  -133.63824 ]]
# Episode: 19/400, Epsilon:0.95, Average reward: -369.02
# Prediction for [500,0,500,0] is: [[-162.86118 -215.1211   -67.7061  -137.35417 -136.11014]]
# Episode: 20/400, Epsilon:0.94, Average reward: -197.39
# Prediction for [500,0,500,0] is: [[-164.07584  -216.66019   -69.969765 -140.01404  -138.37488 ]]
# Weights succesfully copied to Target model.
# Episode: 21/400, Epsilon:0.94, Average reward: -357.56
# Prediction for [500,0,500,0] is: [[-165.24525 -218.14279  -72.14063 -142.7516  -140.63046]]
# Episode: 22/400, Epsilon:0.94, Average reward: -42.32
# Prediction for [500,0,500,0] is: [[-166.42049 -219.71024  -74.31213 -145.36684 -142.90643]]
# Episode: 23/400, Epsilon:0.93, Average reward: -39.12
# Prediction for [500,0,500,0] is: [[-167.75647 -221.11407  -76.55634 -147.83926 -145.45387]]
# Episode: 24/400, Epsilon:0.93, Average reward: -208.45
# Prediction for [500,0,500,0] is: [[-169.3136   -222.47372   -78.588875 -150.35612  -147.97626 ]]
# Episode: 25/400, Epsilon:0.93, Average reward: -32.29
# Prediction for [500,0,500,0] is: [[-170.85501  -223.80872   -80.730896 -152.93703  -150.32153 ]]
# New best agent found. Saved in C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\Single_Cross_Straight\Single_Cross_Straight_Episodes400_ProgramDuelingDDQN_BestAgent0_Memory.p
# Weights succesfully copied to Target model.
# Episode: 26/400, Epsilon:0.92, Average reward: -236.33
# Prediction for [500,0,500,0] is: [[-172.44095 -225.12756  -82.98128 -155.51762 -152.60599]]
# Episode: 27/400, Epsilon:0.92, Average reward: -191.7
# Prediction for [500,0,500,0] is: [[-173.90051 -226.36754  -85.30811 -158.15202 -155.0469 ]]
# Episode: 28/400, Epsilon:0.92, Average reward: -341.88
# Prediction for [500,0,500,0] is: [[-175.289   -227.73334  -87.42133 -160.78568 -157.46802]]
# Episode: 29/400, Epsilon:0.92, Average reward: -368.2
# Prediction for [500,0,500,0] is: [[-176.62874 -229.12918  -89.59053 -163.5678  -159.97816]]
# Episode: 30/400, Epsilon:0.91, Average reward: -210.62
# Prediction for [500,0,500,0] is: [[-177.92259 -230.43982  -91.6165  -166.36705 -162.71202]]
# Weights succesfully copied to Target model.
# Episode: 31/400, Epsilon:0.91, Average reward: -221.03
# Prediction for [500,0,500,0] is: [[-179.29773 -231.69722  -93.8118  -169.07388 -165.49123]]
# Episode: 32/400, Epsilon:0.91, Average reward: -316.63
# Prediction for [500,0,500,0] is: [[-180.7443  -232.90973  -95.96123 -171.81122 -168.39622]]
# Episode: 33/400, Epsilon:0.9, Average reward: -101.65
# Prediction for [500,0,500,0] is: [[-182.2369  -234.13722  -98.29371 -174.5042  -171.18634]]
# Episode: 34/400, Epsilon:0.9, Average reward: -80.53
# Prediction for [500,0,500,0] is: [[-183.7744  -235.35681 -100.74718 -177.08862 -174.0097 ]]
# Episode: 35/400, Epsilon:0.9, Average reward: -90.97
# Prediction for [500,0,500,0] is: [[-185.45671 -236.59268 -103.006   -179.70656 -176.71655]]
# Weights succesfully copied to Target model.
# Episode: 36/400, Epsilon:0.89, Average reward: -215.64
# Prediction for [500,0,500,0] is: [[-187.0007  -237.89029 -105.02859 -182.67105 -179.57423]]
# Episode: 37/400, Epsilon:0.89, Average reward: -215.6
# Prediction for [500,0,500,0] is: [[-188.52454 -239.12569 -107.0355  -185.79956 -182.5036 ]]
# Episode: 38/400, Epsilon:0.89, Average reward: -226.97
# Prediction for [500,0,500,0] is: [[-189.96347 -240.31631 -109.07068 -189.1973  -185.29631]]
# Episode: 39/400, Epsilon:0.89, Average reward: -269.54
# Prediction for [500,0,500,0] is: [[-191.34714 -241.60486 -111.25214 -192.55066 -187.95781]]
# Episode: 40/400, Epsilon:0.88, Average reward: -211.06
# Prediction for [500,0,500,0] is: [[-192.74043 -242.87671 -113.63401 -195.74373 -190.5697 ]]
# Weights succesfully copied to Target model.
# Episode: 41/400, Epsilon:0.88, Average reward: -72.5
# Prediction for [500,0,500,0] is: [[-194.17813 -244.21983 -115.98038 -198.6861  -193.16022]]
# Episode: 42/400, Epsilon:0.88, Average reward: -39.18
# Prediction for [500,0,500,0] is: [[-195.7961  -245.61093 -118.13941 -201.51534 -195.81757]]
# Episode: 43/400, Epsilon:0.87, Average reward: -320.04
# Prediction for [500,0,500,0] is: [[-197.37152 -246.8937  -120.24665 -204.42046 -198.53456]]
# Episode: 44/400, Epsilon:0.87, Average reward: -196.59
# Prediction for [500,0,500,0] is: [[-198.87935 -248.21072 -122.32806 -207.17316 -201.52464]]
# Episode: 45/400, Epsilon:0.87, Average reward: -235.7
# Prediction for [500,0,500,0] is: [[-200.33221 -249.42862 -124.41575 -209.89473 -204.44409]]
# Weights succesfully copied to Target model.
# Episode: 46/400, Epsilon:0.86, Average reward: -214.0
# Prediction for [500,0,500,0] is: [[-202.01068 -250.66702 -126.35384 -212.82794 -207.16693]]
# Episode: 47/400, Epsilon:0.86, Average reward: -70.74
# Prediction for [500,0,500,0] is: [[-203.72272 -251.92165 -128.26065 -215.84947 -209.87015]]
# Episode: 48/400, Epsilon:0.86, Average reward: -340.52
# Prediction for [500,0,500,0] is: [[-205.29701 -253.40016 -130.39674 -218.7488  -212.48932]]
# Episode: 49/400, Epsilon:0.86, Average reward: -288.56
# Prediction for [500,0,500,0] is: [[-207.02242 -254.95804 -132.38681 -221.60277 -215.0511 ]]
# Episode: 50/400, Epsilon:0.85, Average reward: -75.66
# Prediction for [500,0,500,0] is: [[-208.78728 -256.59857 -134.33884 -224.74094 -217.87807]]
# Weights succesfully copied to Target model.
# Episode: 51/400, Epsilon:0.85, Average reward: -197.11
# Prediction for [500,0,500,0] is: [[-210.39058 -258.11655 -136.49393 -227.93256 -220.61278]]
# Episode: 52/400, Epsilon:0.85, Average reward: -54.6
# Prediction for [500,0,500,0] is: [[-211.95067 -259.64822 -138.94733 -231.18578 -223.25793]]
# Episode: 53/400, Epsilon:0.84, Average reward: -315.64
# Prediction for [500,0,500,0] is: [[-213.37234 -261.33923 -141.3046  -234.60272 -225.80022]]
# Episode: 54/400, Epsilon:0.84, Average reward: -76.08
# Prediction for [500,0,500,0] is: [[-214.85493 -263.01135 -143.7891  -238.04292 -228.35016]]
# Episode: 55/400, Epsilon:0.84, Average reward: -61.94
# Prediction for [500,0,500,0] is: [[-216.39323 -264.65543 -146.04105 -241.7184  -231.00558]]
# Weights succesfully copied to Target model.
# Episode: 56/400, Epsilon:0.83, Average reward: -100.63
# Prediction for [500,0,500,0] is: [[-217.91191 -266.2457  -148.19254 -245.45616 -233.72151]]
# Episode: 57/400, Epsilon:0.83, Average reward: -190.3
# Prediction for [500,0,500,0] is: [[-219.46902 -267.7765  -150.28354 -249.03255 -236.42113]]
# Episode: 58/400, Epsilon:0.83, Average reward: -87.51
# Prediction for [500,0,500,0] is: [[-220.99924 -269.33838 -152.6925  -252.32256 -239.00095]]
# Episode: 59/400, Epsilon:0.83, Average reward: -361.36
# Prediction for [500,0,500,0] is: [[-222.57054 -270.9417  -155.1885  -255.46565 -241.55403]]
# Episode: 60/400, Epsilon:0.82, Average reward: -89.04
# Prediction for [500,0,500,0] is: [[-224.12514 -272.52567 -157.55699 -258.75385 -244.18762]]
# Weights succesfully copied to Target model.
# Episode: 61/400, Epsilon:0.82, Average reward: -103.1
# Prediction for [500,0,500,0] is: [[-225.62852 -274.01523 -160.06401 -262.15298 -246.82448]]
# Episode: 62/400, Epsilon:0.82, Average reward: -210.17
# Prediction for [500,0,500,0] is: [[-227.16162 -275.47348 -162.3836  -265.73245 -249.46107]]
# Episode: 63/400, Epsilon:0.81, Average reward: -44.73
# Prediction for [500,0,500,0] is: [[-228.71532 -277.04477 -164.85938 -269.06863 -251.90218]]
# Episode: 64/400, Epsilon:0.81, Average reward: -73.9
# Prediction for [500,0,500,0] is: [[-230.20879 -278.6461  -167.4509  -272.3676  -254.19344]]
# Episode: 65/400, Epsilon:0.81, Average reward: -358.32
# Prediction for [500,0,500,0] is: [[-231.57544 -280.44308 -169.92068 -275.76468 -256.45428]]
# Weights succesfully copied to Target model.
# Episode: 66/400, Epsilon:0.8, Average reward: -234.52
# Prediction for [500,0,500,0] is: [[-232.86922 -282.12317 -172.262   -279.27435 -258.96112]]
# Episode: 67/400, Epsilon:0.8, Average reward: -363.96
# Prediction for [500,0,500,0] is: [[-234.17923 -283.801   -174.75903 -282.53845 -261.5821 ]]
# Episode: 68/400, Epsilon:0.8, Average reward: -39.09
# Prediction for [500,0,500,0] is: [[-235.44167 -285.52197 -177.19153 -285.7071  -264.4228 ]]
# Episode: 69/400, Epsilon:0.8, Average reward: -191.88
# Prediction for [500,0,500,0] is: [[-236.67577 -287.21432 -179.64001 -289.05292 -267.33917]]
# Episode: 70/400, Epsilon:0.79, Average reward: -106.83
# Prediction for [500,0,500,0] is: [[-238.01198 -288.80383 -182.10286 -292.2833  -270.40594]]
# Weights succesfully copied to Target model.
# Episode: 71/400, Epsilon:0.79, Average reward: -133.14
# Prediction for [500,0,500,0] is: [[-239.486   -290.40225 -184.5199  -295.3355  -273.68008]]
# Episode: 72/400, Epsilon:0.79, Average reward: -258.33
# Prediction for [500,0,500,0] is: [[-241.00864 -291.9459  -186.66705 -298.61325 -276.955  ]]
# Episode: 73/400, Epsilon:0.78, Average reward: -56.05
# Prediction for [500,0,500,0] is: [[-242.63571 -293.58154 -188.96347 -301.6593  -280.30917]]
# Episode: 74/400, Epsilon:0.78, Average reward: -23.46
# Prediction for [500,0,500,0] is: [[-0.07491341 -0.07110731 -0.11684917 -0.19560829 -0.17454222]]
# New best agent found. Saved in C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\Single_Cross_Straight\Single_Cross_Straight_Episodes400_ProgramDuelingDDQN_BestAgent0_Memory.p
# Episode: 75/400, Epsilon:0.78, Average reward: -346.2
# Prediction for [500,0,500,0] is: [[-0.07619724 -0.07229516 -0.11853081 -0.1984497  -0.17744976]]
# Weights succesfully copied to Target model.
# Episode: 76/400, Epsilon:0.77, Average reward: -212.34
# Prediction for [500,0,500,0] is: [[-0.07741018 -0.07355244 -0.12030856 -0.20162705 -0.18024233]]
# Episode: 77/400, Epsilon:0.77, Average reward: -79.59
# Prediction for [500,0,500,0] is: [[-0.07853805 -0.07477163 -0.12199798 -0.20481074 -0.18300831]]
# Episode: 78/400, Epsilon:0.77, Average reward: -388.09
# Prediction for [500,0,500,0] is: [[-0.07965201 -0.07595594 -0.12360576 -0.20800292 -0.18579489]]
# Episode: 79/400, Epsilon:0.77, Average reward: -39.55
# Prediction for [500,0,500,0] is: [[-0.08080925 -0.07706511 -0.12524925 -0.21110447 -0.18848157]]
# Episode: 80/400, Epsilon:0.76, Average reward: -40.88
# Prediction for [500,0,500,0] is: [[-0.08191131 -0.07816307 -0.12706786 -0.21418339 -0.19100952]]
# Weights succesfully copied to Target model.
# Episode: 81/400, Epsilon:0.76, Average reward: -374.65
# Prediction for [500,0,500,0] is: [[-0.08299558 -0.07914387 -0.12900046 -0.21710008 -0.19343781]]
# Episode: 82/400, Epsilon:0.76, Average reward: -259.58
# Prediction for [500,0,500,0] is: [[-0.08405313 -0.08009751 -0.13101898 -0.21985224 -0.19599566]]
# Episode: 83/400, Epsilon:0.75, Average reward: -233.94
# Prediction for [500,0,500,0] is: [[-0.08517209 -0.08116694 -0.13283025 -0.22253852 -0.19844835]]
# Episode: 84/400, Epsilon:0.75, Average reward: -235.69
# Prediction for [500,0,500,0] is: [[-0.08634471 -0.08236564 -0.13442141 -0.22517091 -0.20082298]]
# Episode: 85/400, Epsilon:0.75, Average reward: -38.54
# Prediction for [500,0,500,0] is: [[-0.08756445 -0.08357598 -0.13597487 -0.22765905 -0.20316291]]
# Weights succesfully copied to Target model.
# Episode: 86/400, Epsilon:0.74, Average reward: -92.99
# Prediction for [500,0,500,0] is: [[-0.08877921 -0.08488661 -0.13746731 -0.23005074 -0.20535299]]
# Episode: 87/400, Epsilon:0.74, Average reward: -195.92
# Prediction for [500,0,500,0] is: [[-0.08996095 -0.08628066 -0.13901383 -0.23234005 -0.20747316]]
# Episode: 88/400, Epsilon:0.74, Average reward: -364.61
# Prediction for [500,0,500,0] is: [[-0.09123206 -0.08756167 -0.14048067 -0.2345731  -0.20974551]]
# Episode: 89/400, Epsilon:0.74, Average reward: -194.94
# Prediction for [500,0,500,0] is: [[-0.09245571 -0.08881876 -0.14181365 -0.23679462 -0.21214083]]
# Episode: 90/400, Epsilon:0.73, Average reward: -55.49
# Prediction for [500,0,500,0] is: [[-0.09366319 -0.09017131 -0.14320727 -0.23896539 -0.2145425 ]]
# Weights succesfully copied to Target model.
# Episode: 91/400, Epsilon:0.73, Average reward: -49.07
# Prediction for [500,0,500,0] is: [[-0.09489179 -0.09147077 -0.14449245 -0.241322   -0.21688142]]
# Episode: 92/400, Epsilon:0.73, Average reward: -31.35
# Prediction for [500,0,500,0] is: [[-0.09601886 -0.09272557 -0.14587083 -0.24386127 -0.21913002]]
# Episode: 93/400, Epsilon:0.72, Average reward: -205.5
# Prediction for [500,0,500,0] is: [[-0.0971676  -0.09403924 -0.14727639 -0.24635026 -0.22127247]]
# Episode: 94/400, Epsilon:0.72, Average reward: -109.15
# Prediction for [500,0,500,0] is: [[-0.0983399  -0.09523373 -0.14867648 -0.24877787 -0.22345713]]
# Episode: 95/400, Epsilon:0.72, Average reward: -362.91
# Prediction for [500,0,500,0] is: [[-0.09948699 -0.09649064 -0.14998819 -0.25134432 -0.22566536]]
# Weights succesfully copied to Target model.
# Episode: 96/400, Epsilon:0.71, Average reward: -40.64
# Prediction for [500,0,500,0] is: [[-0.10050504 -0.09771588 -0.15132992 -0.25409386 -0.22795647]]
# Episode: 97/400, Epsilon:0.71, Average reward: -56.78
# Prediction for [500,0,500,0] is: [[-0.10153729 -0.09890895 -0.15278018 -0.2567894  -0.23015393]]
# Episode: 98/400, Epsilon:0.71, Average reward: -71.87
# Prediction for [500,0,500,0] is: [[-0.10261589 -0.10008698 -0.15420987 -0.25964785 -0.23228063]]
# Episode: 99/400, Epsilon:0.71, Average reward: -47.44
# Prediction for [500,0,500,0] is: [[-0.10369165 -0.10121045 -0.15556967 -0.26263332 -0.23448548]]
# Episode: 100/400, Epsilon:0.7, Average reward: -64.48
# Prediction for [500,0,500,0] is: [[-0.10476861 -0.10224967 -0.15695347 -0.26561502 -0.236785  ]]
# Weights succesfully copied to Target model.
# Saving architecture, weights and optimizer state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Saved Partial results at the end of episode 100.
# Sever Redispatched.
# Redispatched
# Episode: 101/400, Epsilon:0.7, Average reward: -65.65
# Prediction for [500,0,500,0] is: [[-0.10581144 -0.10321867 -0.15826322 -0.2684784  -0.23923622]]
# Episode: 102/400, Epsilon:0.7, Average reward: -103.92
# Prediction for [500,0,500,0] is: [[-0.10689059 -0.10422352 -0.15955836 -0.27118635 -0.24150266]]
# Episode: 103/400, Epsilon:0.69, Average reward: -69.72
# Prediction for [500,0,500,0] is: [[-0.10803649 -0.10520812 -0.16080421 -0.27376884 -0.2437855 ]]
# Episode: 104/400, Epsilon:0.69, Average reward: -43.61
# Prediction for [500,0,500,0] is: [[-0.1092066  -0.10613698 -0.16208169 -0.2762333  -0.24614747]]
# Episode: 105/400, Epsilon:0.69, Average reward: -63.47
# Prediction for [500,0,500,0] is: [[-0.11035238 -0.10712019 -0.16326545 -0.27865854 -0.24862626]]
# Weights succesfully copied to Target model.
# Episode: 106/400, Epsilon:0.68, Average reward: -190.98
# Prediction for [500,0,500,0] is: [[-0.11148622 -0.10806984 -0.1644718  -0.28124422 -0.2509189 ]]
# Episode: 107/400, Epsilon:0.68, Average reward: -229.43
# Prediction for [500,0,500,0] is: [[-0.11260984 -0.108984   -0.16564597 -0.28372532 -0.25339395]]
# Episode: 108/400, Epsilon:0.68, Average reward: -207.82
# Prediction for [500,0,500,0] is: [[-0.11368145 -0.10992356 -0.16686371 -0.2861816  -0.25576684]]
# Episode: 109/400, Epsilon:0.68, Average reward: -218.56
# Prediction for [500,0,500,0] is: [[-0.1147796  -0.11082435 -0.16815157 -0.28862017 -0.25820377]]
# Episode: 110/400, Epsilon:0.67, Average reward: -39.44
# Prediction for [500,0,500,0] is: [[-0.11577798 -0.1117983  -0.16956253 -0.29109043 -0.2604561 ]]
# Weights succesfully copied to Target model.
# Episode: 111/400, Epsilon:0.67, Average reward: -195.34
# Prediction for [500,0,500,0] is: [[-0.11669894 -0.1128047  -0.17101817 -0.29358634 -0.26263785]]
# Episode: 112/400, Epsilon:0.67, Average reward: -121.83
# Prediction for [500,0,500,0] is: [[-0.11761109 -0.11391035 -0.17240286 -0.2961548  -0.26474768]]
# Episode: 113/400, Epsilon:0.66, Average reward: -195.93
# Prediction for [500,0,500,0] is: [[-0.11856833 -0.11510779 -0.17386052 -0.29869714 -0.26676026]]
# Episode: 114/400, Epsilon:0.66, Average reward: -129.3
# Prediction for [500,0,500,0] is: [[-0.11944444 -0.11629682 -0.1753771  -0.30133963 -0.26888478]]
# Episode: 115/400, Epsilon:0.66, Average reward: -301.49
# Prediction for [500,0,500,0] is: [[-0.12039202 -0.11740294 -0.17685752 -0.30381882 -0.27107805]]
# Weights succesfully copied to Target model.
# Episode: 116/400, Epsilon:0.65, Average reward: -40.8
# Prediction for [500,0,500,0] is: [[-0.12137099 -0.11859381 -0.17821747 -0.30625293 -0.2733435 ]]
# Episode: 117/400, Epsilon:0.65, Average reward: -58.43
# Prediction for [500,0,500,0] is: [[-0.12237443 -0.11974271 -0.17943513 -0.30883616 -0.27569348]]
# Episode: 118/400, Epsilon:0.65, Average reward: -219.69
# Prediction for [500,0,500,0] is: [[-0.12336239 -0.12089433 -0.18072712 -0.3114368  -0.27797225]]
# Episode: 119/400, Epsilon:0.65, Average reward: -77.15
# Prediction for [500,0,500,0] is: [[-0.12438131 -0.12195671 -0.18204482 -0.31385332 -0.28020778]]
# Episode: 120/400, Epsilon:0.64, Average reward: -208.66
# Prediction for [500,0,500,0] is: [[-0.12540159 -0.12299342 -0.183542   -0.31617355 -0.28241882]]
# Weights succesfully copied to Target model.
# Episode: 121/400, Epsilon:0.64, Average reward: -62.84
# Prediction for [500,0,500,0] is: [[-0.12644124 -0.12392676 -0.18500105 -0.31847286 -0.284846  ]]
# Episode: 122/400, Epsilon:0.64, Average reward: -82.15
# Prediction for [500,0,500,0] is: [[-0.1274913  -0.12485617 -0.1866554  -0.3205564  -0.2871919 ]]
# Episode: 123/400, Epsilon:0.63, Average reward: -54.04
# Prediction for [500,0,500,0] is: [[-0.12844849 -0.12581575 -0.18850966 -0.32263902 -0.28960535]]
# Episode: 124/400, Epsilon:0.63, Average reward: -65.17
# Prediction for [500,0,500,0] is: [[-0.1293655  -0.12692843 -0.19033483 -0.3247734  -0.29189867]]
# Episode: 125/400, Epsilon:0.63, Average reward: -292.15
# Prediction for [500,0,500,0] is: [[-0.13042018 -0.12812379 -0.19191849 -0.32690346 -0.29425168]]
# Weights succesfully copied to Target model.
# Episode: 126/400, Epsilon:0.62, Average reward: -37.37
# Prediction for [500,0,500,0] is: [[-0.1314897  -0.12939411 -0.19334297 -0.32902968 -0.29650918]]
# Episode: 127/400, Epsilon:0.62, Average reward: -316.92
# Prediction for [500,0,500,0] is: [[-0.13255876 -0.13058542 -0.1946495  -0.3312437  -0.29903078]]
# Episode: 128/400, Epsilon:0.62, Average reward: -316.11
# Prediction for [500,0,500,0] is: [[-0.13361397 -0.13168842 -0.19612801 -0.33337423 -0.30145827]]
# Episode: 129/400, Epsilon:0.62, Average reward: -31.45
# Prediction for [500,0,500,0] is: [[-0.13461912 -0.13278697 -0.19769907 -0.33560905 -0.3040301 ]]
# Episode: 130/400, Epsilon:0.61, Average reward: -58.41
# Prediction for [500,0,500,0] is: [[-0.13555378 -0.13382584 -0.19933978 -0.33817762 -0.3067351 ]]
# Weights succesfully copied to Target model.
# Episode: 131/400, Epsilon:0.61, Average reward: -95.8
# Prediction for [500,0,500,0] is: [[-0.13651185 -0.13503498 -0.20087388 -0.3406397  -0.3093343 ]]
# Episode: 132/400, Epsilon:0.61, Average reward: -52.5
# Prediction for [500,0,500,0] is: [[-0.13741489 -0.13625124 -0.20239387 -0.34308168 -0.31182754]]
# Episode: 133/400, Epsilon:0.6, Average reward: -192.15
# Prediction for [500,0,500,0] is: [[-0.1382502  -0.13743296 -0.20396361 -0.34546155 -0.31452072]]
# Episode: 134/400, Epsilon:0.6, Average reward: -383.66
# Prediction for [500,0,500,0] is: [[-0.1390969  -0.13867204 -0.20537701 -0.34787878 -0.31723052]]
# Episode: 135/400, Epsilon:0.6, Average reward: -74.59
# Prediction for [500,0,500,0] is: [[-0.1400271  -0.13997695 -0.20685843 -0.35030437 -0.3197465 ]]
# Weights succesfully copied to Target model.
# Episode: 136/400, Epsilon:0.59, Average reward: -205.25
# Prediction for [500,0,500,0] is: [[-0.14093977 -0.14126912 -0.20836729 -0.35293323 -0.32215795]]
# Episode: 137/400, Epsilon:0.59, Average reward: -58.57
# Prediction for [500,0,500,0] is: [[-0.14179568 -0.14259657 -0.2098839  -0.3557341  -0.3244716 ]]
# Episode: 138/400, Epsilon:0.59, Average reward: -70.07
# Prediction for [500,0,500,0] is: [[-0.142625   -0.14388339 -0.21124476 -0.3585471  -0.32674822]]
# Episode: 139/400, Epsilon:0.59, Average reward: -60.8
# Prediction for [500,0,500,0] is: [[-0.14341187 -0.14512938 -0.2126216  -0.3615129  -0.32896757]]
# Episode: 140/400, Epsilon:0.58, Average reward: -79.06
# Prediction for [500,0,500,0] is: [[-0.14417422 -0.14639904 -0.21390867 -0.36446667 -0.33121654]]
# Weights succesfully copied to Target model.
# Episode: 141/400, Epsilon:0.58, Average reward: -84.41
# Prediction for [500,0,500,0] is: [[-0.14493848 -0.14765975 -0.21530503 -0.36725792 -0.33356148]]
# Episode: 142/400, Epsilon:0.58, Average reward: -66.83
# Prediction for [500,0,500,0] is: [[-0.14576498 -0.14882448 -0.21674234 -0.37009248 -0.3358629 ]]
# Episode: 143/400, Epsilon:0.57, Average reward: -38.05
# Prediction for [500,0,500,0] is: [[-0.14665228 -0.1499266  -0.21801752 -0.37302798 -0.33823478]]
# Episode: 144/400, Epsilon:0.57, Average reward: -196.38
# Prediction for [500,0,500,0] is: [[-0.14761254 -0.15102753 -0.2191002  -0.37587765 -0.34082997]]
# Episode: 145/400, Epsilon:0.57, Average reward: -48.35
# Prediction for [500,0,500,0] is: [[-0.14857203 -0.15202853 -0.2201428  -0.3785028  -0.3434062 ]]
# Weights succesfully copied to Target model.
# Episode: 146/400, Epsilon:0.56, Average reward: -93.46
# Prediction for [500,0,500,0] is: [[-0.14946818 -0.15303788 -0.22130385 -0.3810849  -0.34584355]]
# Episode: 147/400, Epsilon:0.56, Average reward: -103.2
# Prediction for [500,0,500,0] is: [[-0.15030497 -0.15411349 -0.22248617 -0.38379967 -0.3481082 ]]
# Episode: 148/400, Epsilon:0.56, Average reward: -44.7
# Prediction for [500,0,500,0] is: [[-0.15113166 -0.15521032 -0.22374322 -0.38635433 -0.35033798]]
# Episode: 149/400, Epsilon:0.56, Average reward: -197.99
# Prediction for [500,0,500,0] is: [[-0.15195401 -0.1562598  -0.22506516 -0.3889829  -0.3526122 ]]
# Episode: 150/400, Epsilon:0.55, Average reward: -200.87
# Prediction for [500,0,500,0] is: [[-0.15284112 -0.15726602 -0.22628468 -0.39164057 -0.35493   ]]
# Weights succesfully copied to Target model.
# Episode: 151/400, Epsilon:0.55, Average reward: -72.65
# Prediction for [500,0,500,0] is: [[-0.15373093 -0.15825793 -0.22776496 -0.394295   -0.35709268]]
# Episode: 152/400, Epsilon:0.55, Average reward: -39.52
# Prediction for [500,0,500,0] is: [[-0.15456754 -0.15930179 -0.22923848 -0.39693397 -0.35910064]]
# Episode: 153/400, Epsilon:0.54, Average reward: -327.74
# Prediction for [500,0,500,0] is: [[-0.1553953  -0.16034158 -0.23077708 -0.39950746 -0.36107993]]
# Episode: 154/400, Epsilon:0.54, Average reward: -105.71
# Prediction for [500,0,500,0] is: [[-0.15620258 -0.16137928 -0.23226953 -0.4020034  -0.36305138]]
# Episode: 155/400, Epsilon:0.54, Average reward: -28.32
# Prediction for [500,0,500,0] is: [[-0.15698624 -0.16249898 -0.23390718 -0.40451366 -0.36500755]]
# Weights succesfully copied to Target model.
# Episode: 156/400, Epsilon:0.53, Average reward: -59.52
# Prediction for [500,0,500,0] is: [[-0.15784872 -0.1635805  -0.23545545 -0.40698233 -0.36697108]]
# Episode: 157/400, Epsilon:0.53, Average reward: -202.15
# Prediction for [500,0,500,0] is: [[-0.15867814 -0.16467923 -0.23705433 -0.40930542 -0.36882514]]
# Episode: 158/400, Epsilon:0.53, Average reward: -199.82
# Prediction for [500,0,500,0] is: [[-0.15949571 -0.1658812  -0.23854695 -0.4118349  -0.37074947]]
# Episode: 159/400, Epsilon:0.53, Average reward: -189.92
# Prediction for [500,0,500,0] is: [[-0.16030341 -0.16709352 -0.23992603 -0.4143737  -0.3726623 ]]
# Episode: 160/400, Epsilon:0.52, Average reward: -55.1
# Prediction for [500,0,500,0] is: [[-0.16112527 -0.16825058 -0.24146697 -0.41683817 -0.37462682]]
# Weights succesfully copied to Target model.
# Episode: 161/400, Epsilon:0.52, Average reward: -66.17
# Prediction for [500,0,500,0] is: [[-0.16191798 -0.16938317 -0.24313125 -0.41936728 -0.37661093]]
# Episode: 162/400, Epsilon:0.52, Average reward: -50.05
# Prediction for [500,0,500,0] is: [[-0.16267915 -0.17055637 -0.24466172 -0.42204857 -0.37855363]]
# Episode: 163/400, Epsilon:0.51, Average reward: -42.49
# Prediction for [500,0,500,0] is: [[-0.16353413 -0.17173152 -0.24604046 -0.42461812 -0.38065055]]
# Episode: 164/400, Epsilon:0.51, Average reward: -224.69
# Prediction for [500,0,500,0] is: [[-0.16444968 -0.17281628 -0.24737507 -0.42700583 -0.38290307]]
# Episode: 165/400, Epsilon:0.51, Average reward: -67.03
# Prediction for [500,0,500,0] is: [[-0.16532665 -0.17396659 -0.24864233 -0.42942053 -0.3851087 ]]
# Weights succesfully copied to Target model.
# Episode: 166/400, Epsilon:0.5, Average reward: -45.7
# Prediction for [500,0,500,0] is: [[-0.16622612 -0.17509773 -0.24981481 -0.43186766 -0.38727906]]
# Episode: 167/400, Epsilon:0.5, Average reward: -76.5
# Prediction for [500,0,500,0] is: [[-0.16710177 -0.17614636 -0.25094888 -0.43429425 -0.38957447]]
# Episode: 168/400, Epsilon:0.5, Average reward: -42.38
# Prediction for [500,0,500,0] is: [[-0.16804749 -0.17717272 -0.25201446 -0.4366312  -0.39190304]]
# Episode: 169/400, Epsilon:0.5, Average reward: -40.27
# Prediction for [500,0,500,0] is: [[-0.16900769 -0.17814651 -0.25313812 -0.43895444 -0.39427534]]
# Episode: 170/400, Epsilon:0.49, Average reward: -40.03
# Prediction for [500,0,500,0] is: [[-0.16993016 -0.17915481 -0.25425997 -0.44120803 -0.39638233]]
# Weights succesfully copied to Target model.
# Episode: 171/400, Epsilon:0.49, Average reward: -77.24
# Prediction for [500,0,500,0] is: [[-0.17092338 -0.1801039  -0.25540525 -0.44340026 -0.39844996]]
# Episode: 172/400, Epsilon:0.49, Average reward: -92.71
# Prediction for [500,0,500,0] is: [[-0.17190874 -0.18109621 -0.2565278  -0.44580448 -0.40047508]]
# Episode: 173/400, Epsilon:0.48, Average reward: -117.83
# Prediction for [500,0,500,0] is: [[-0.17281517 -0.18203542 -0.25775498 -0.44832152 -0.40258256]]
# Episode: 174/400, Epsilon:0.48, Average reward: -63.6
# Prediction for [500,0,500,0] is: [[-0.17370811 -0.18299451 -0.2591162  -0.45072556 -0.40471435]]
# Episode: 175/400, Epsilon:0.48, Average reward: -65.02
# Prediction for [500,0,500,0] is: [[-0.17459044 -0.18394941 -0.2606753  -0.45295316 -0.40691048]]
# Weights succesfully copied to Target model.
# Episode: 176/400, Epsilon:0.47, Average reward: -197.26
# Prediction for [500,0,500,0] is: [[-0.17554715 -0.18488532 -0.26230255 -0.45520163 -0.40913498]]
# Episode: 177/400, Epsilon:0.47, Average reward: -46.65
# Prediction for [500,0,500,0] is: [[-0.1765008  -0.18585189 -0.26392096 -0.4573715  -0.41128957]]
# Episode: 178/400, Epsilon:0.47, Average reward: -41.14
# Prediction for [500,0,500,0] is: [[-0.17749748 -0.18687473 -0.26535317 -0.4596159  -0.41354543]]
# Episode: 179/400, Epsilon:0.47, Average reward: -46.11
# Prediction for [500,0,500,0] is: [[-0.17850034 -0.18779698 -0.2667543  -0.46204066 -0.4159217 ]]
# Episode: 180/400, Epsilon:0.46, Average reward: -354.55
# Prediction for [500,0,500,0] is: [[-0.17953834 -0.18868452 -0.2681884  -0.46433407 -0.41819575]]
# Weights succesfully copied to Target model.
# Episode: 181/400, Epsilon:0.46, Average reward: -175.78
# Prediction for [500,0,500,0] is: [[-0.18050998 -0.18971711 -0.26955003 -0.4667398  -0.4202659 ]]
# Episode: 182/400, Epsilon:0.46, Average reward: -61.34
# Prediction for [500,0,500,0] is: [[-0.18150006 -0.1907064  -0.27083942 -0.46929735 -0.42243063]]
# Episode: 183/400, Epsilon:0.45, Average reward: -77.3
# Prediction for [500,0,500,0] is: [[-0.18254037 -0.19163698 -0.27214652 -0.47201127 -0.4246716 ]]
# Episode: 184/400, Epsilon:0.45, Average reward: -75.52
# Prediction for [500,0,500,0] is: [[-0.1835239  -0.19260307 -0.27346146 -0.47477967 -0.4269751 ]]
# Episode: 185/400, Epsilon:0.45, Average reward: -206.68
# Prediction for [500,0,500,0] is: [[-0.18446895 -0.1935701  -0.27460843 -0.47759926 -0.42932096]]
# Weights succesfully copied to Target model.
# Episode: 186/400, Epsilon:0.44, Average reward: -88.83
# Prediction for [500,0,500,0] is: [[-0.18546475 -0.1946044  -0.27562645 -0.48033345 -0.4317068 ]]
# Episode: 187/400, Epsilon:0.44, Average reward: -49.38
# Prediction for [500,0,500,0] is: [[-0.18647614 -0.19561231 -0.27663293 -0.48291048 -0.4344322 ]]
# Episode: 188/400, Epsilon:0.44, Average reward: -229.95
# Prediction for [500,0,500,0] is: [[-0.18749377 -0.19655241 -0.27767193 -0.48533565 -0.43707126]]
# Episode: 189/400, Epsilon:0.44, Average reward: -31.39
# Prediction for [500,0,500,0] is: [[-0.1884832  -0.1974533  -0.27880037 -0.4879962  -0.43976715]]
# Episode: 190/400, Epsilon:0.43, Average reward: -96.78
# Prediction for [500,0,500,0] is: [[-0.18952146 -0.19840497 -0.2798235  -0.4906396  -0.44237143]]
# Weights succesfully copied to Target model.
# Episode: 191/400, Epsilon:0.43, Average reward: -196.73
# Prediction for [500,0,500,0] is: [[-0.19061875 -0.1993696  -0.28080177 -0.49329078 -0.44487438]]
# Episode: 192/400, Epsilon:0.43, Average reward: -54.21
# Prediction for [500,0,500,0] is: [[-0.1917045  -0.20038494 -0.28182873 -0.4959787  -0.44722676]]
# Episode: 193/400, Epsilon:0.42, Average reward: -93.77
# Prediction for [500,0,500,0] is: [[-0.19274913 -0.20151338 -0.28293666 -0.49849337 -0.4492845 ]]
# Episode: 194/400, Epsilon:0.42, Average reward: -355.62
# Prediction for [500,0,500,0] is: [[-0.19382773 -0.20265111 -0.28393835 -0.5010421  -0.45142335]]
# Episode: 195/400, Epsilon:0.42, Average reward: -54.97
# Prediction for [500,0,500,0] is: [[-0.194902   -0.20387381 -0.28499302 -0.50347614 -0.4533999 ]]
# Weights succesfully copied to Target model.
# Episode: 196/400, Epsilon:0.41, Average reward: -39.17
# Prediction for [500,0,500,0] is: [[-0.19603096 -0.20500143 -0.2859747  -0.5058697  -0.4553636 ]]
# Episode: 197/400, Epsilon:0.41, Average reward: -33.16
# Prediction for [500,0,500,0] is: [[-0.19709113 -0.20610265 -0.28708363 -0.5080854  -0.45730194]]
# Episode: 198/400, Epsilon:0.41, Average reward: -227.99
# Prediction for [500,0,500,0] is: [[-0.19811319 -0.2071245  -0.28814274 -0.51048225 -0.45948   ]]
# Episode: 199/400, Epsilon:0.41, Average reward: -194.7
# Prediction for [500,0,500,0] is: [[-0.19906491 -0.20809594 -0.2892717  -0.51296484 -0.46184367]]
# Episode: 200/400, Epsilon:0.4, Average reward: -44.01
# Prediction for [500,0,500,0] is: [[-0.20004459 -0.20902838 -0.29036942 -0.515509   -0.46427208]]
# Weights succesfully copied to Target model.
# Saving architecture, weights and optimizer state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Saved Partial results at the end of episode 200.
# Sever Redispatched.
# Redispatched
# Episode: 201/400, Epsilon:0.4, Average reward: -43.82
# Prediction for [500,0,500,0] is: [[-0.20099832 -0.20992598 -0.29136693 -0.5183581  -0.46674255]]
# Episode: 202/400, Epsilon:0.4, Average reward: -43.14
# Prediction for [500,0,500,0] is: [[-0.20199428 -0.21085408 -0.29240608 -0.5212586  -0.46907482]]
# Episode: 203/400, Epsilon:0.39, Average reward: -46.69
# Prediction for [500,0,500,0] is: [[-0.20295312 -0.21180451 -0.29350755 -0.5241765  -0.47118282]]
# Episode: 204/400, Epsilon:0.39, Average reward: -45.66
# Prediction for [500,0,500,0] is: [[-0.2039649  -0.21275659 -0.29459327 -0.52697384 -0.4732738 ]]
# Episode: 205/400, Epsilon:0.39, Average reward: -55.26
# Prediction for [500,0,500,0] is: [[-0.20495634 -0.21375234 -0.29562548 -0.52985823 -0.4754694 ]]
# Weights succesfully copied to Target model.
# Episode: 206/400, Epsilon:0.38, Average reward: -81.2
# Prediction for [500,0,500,0] is: [[-0.2059327  -0.21467698 -0.29663175 -0.5327321  -0.47769243]]
# Episode: 207/400, Epsilon:0.38, Average reward: -58.47
# Prediction for [500,0,500,0] is: [[-0.206944   -0.21549131 -0.29760846 -0.535525   -0.4800353 ]]
# Episode: 208/400, Epsilon:0.38, Average reward: -85.83
# Prediction for [500,0,500,0] is: [[-0.20798954 -0.21631621 -0.29867414 -0.53828406 -0.4823762 ]]
# Episode: 209/400, Epsilon:0.38, Average reward: -39.29
# Prediction for [500,0,500,0] is: [[-0.20902161 -0.21713656 -0.29969996 -0.54105777 -0.48479605]]
# Episode: 210/400, Epsilon:0.37, Average reward: -251.47
# Prediction for [500,0,500,0] is: [[-0.21006803 -0.21802856 -0.30069634 -0.5434799  -0.48721558]]
# Weights succesfully copied to Target model.
# Episode: 211/400, Epsilon:0.37, Average reward: -60.57
# Prediction for [500,0,500,0] is: [[-0.21114753 -0.21897453 -0.30166885 -0.5458857  -0.48953632]]
# Episode: 212/400, Epsilon:0.37, Average reward: -87.4
# Prediction for [500,0,500,0] is: [[-0.21220422 -0.21991745 -0.30263287 -0.5483303  -0.49180412]]
# Episode: 213/400, Epsilon:0.36, Average reward: -92.51
# Prediction for [500,0,500,0] is: [[-0.21325375 -0.22085719 -0.30371836 -0.550742   -0.4939751 ]]
# Episode: 214/400, Epsilon:0.36, Average reward: -46.98
# Prediction for [500,0,500,0] is: [[-0.2142872  -0.2217286  -0.30473533 -0.5532622  -0.49626273]]
# Episode: 215/400, Epsilon:0.36, Average reward: -57.84
# Prediction for [500,0,500,0] is: [[-0.21531759 -0.22260459 -0.30574828 -0.5556903  -0.49852514]]
# Weights succesfully copied to Target model.
# Episode: 216/400, Epsilon:0.35, Average reward: -220.71
# Prediction for [500,0,500,0] is: [[-0.21640469 -0.22341609 -0.3066967  -0.55801547 -0.50090975]]
# Episode: 217/400, Epsilon:0.35, Average reward: -60.33
# Prediction for [500,0,500,0] is: [[-0.21742815 -0.22415967 -0.30775297 -0.56033015 -0.50317657]]
# Episode: 218/400, Epsilon:0.35, Average reward: -49.81
# Prediction for [500,0,500,0] is: [[-0.21841514 -0.22488266 -0.30886167 -0.5625558  -0.50553024]]
# Episode: 219/400, Epsilon:0.35, Average reward: -65.84
# Prediction for [500,0,500,0] is: [[-0.21939792 -0.22561002 -0.31000897 -0.56473285 -0.5078826 ]]
# Episode: 220/400, Epsilon:0.34, Average reward: -55.13
# Prediction for [500,0,500,0] is: [[-0.22046724 -0.22634007 -0.31111825 -0.566892   -0.5102643 ]]
# Weights succesfully copied to Target model.
# Episode: 221/400, Epsilon:0.34, Average reward: -30.85
# Prediction for [500,0,500,0] is: [[-0.2215392  -0.22703433 -0.31229234 -0.568982   -0.51268685]]
# Episode: 222/400, Epsilon:0.34, Average reward: -50.99
# Prediction for [500,0,500,0] is: [[-0.22257043 -0.22774372 -0.3134964  -0.57116437 -0.5149418 ]]
# Episode: 223/400, Epsilon:0.33, Average reward: -33.01
# Prediction for [500,0,500,0] is: [[-0.22363828 -0.22842617 -0.31472653 -0.57346684 -0.51722354]]
# Episode: 224/400, Epsilon:0.33, Average reward: -197.78
# Prediction for [500,0,500,0] is: [[-0.22488146 -0.22907585 -0.31576517 -0.57599455 -0.5197343 ]]
# Episode: 225/400, Epsilon:0.33, Average reward: -40.76
# Prediction for [500,0,500,0] is: [[-0.22615886 -0.22984535 -0.3167854  -0.5785144  -0.5219542 ]]
# Weights succesfully copied to Target model.
# Episode: 226/400, Epsilon:0.32, Average reward: -54.31
# Prediction for [500,0,500,0] is: [[-0.22738923 -0.23066159 -0.31786692 -0.5809958  -0.52401984]]
# Episode: 227/400, Epsilon:0.32, Average reward: -186.5
# Prediction for [500,0,500,0] is: [[-0.22860147 -0.23143959 -0.31897187 -0.5834967  -0.52612174]]
# Episode: 228/400, Epsilon:0.32, Average reward: -44.03
# Prediction for [500,0,500,0] is: [[-0.22973655 -0.2323298  -0.32012966 -0.58606005 -0.52825826]]
# Episode: 229/400, Epsilon:0.31, Average reward: -95.94
# Prediction for [500,0,500,0] is: [[-0.23081811 -0.23325102 -0.321396   -0.58847606 -0.5302453 ]]
# Episode: 230/400, Epsilon:0.31, Average reward: -193.49
# Prediction for [500,0,500,0] is: [[-0.23186204 -0.23416613 -0.322648   -0.5908813  -0.5322478 ]]
# Weights succesfully copied to Target model.
# Episode: 231/400, Epsilon:0.31, Average reward: -79.33
# Prediction for [500,0,500,0] is: [[-0.2328966  -0.23509344 -0.32390285 -0.5934764  -0.5342281 ]]
# Episode: 232/400, Epsilon:0.31, Average reward: -234.51
# Prediction for [500,0,500,0] is: [[-0.23401377 -0.23600844 -0.32515118 -0.5959863  -0.5362687 ]]
# Episode: 233/400, Epsilon:0.3, Average reward: -79.69
# Prediction for [500,0,500,0] is: [[-0.23521097 -0.23698406 -0.32637662 -0.5983119  -0.53843594]]
# Episode: 234/400, Epsilon:0.3, Average reward: -225.88
# Prediction for [500,0,500,0] is: [[-0.23645283 -0.2379965  -0.32745934 -0.60051435 -0.54065233]]
# Episode: 235/400, Epsilon:0.3, Average reward: -58.66
# Prediction for [500,0,500,0] is: [[-0.23756322 -0.23905747 -0.32858092 -0.6026521  -0.5426405 ]]
# Weights succesfully copied to Target model.
# Episode: 236/400, Epsilon:0.29, Average reward: -54.36
# Prediction for [500,0,500,0] is: [[-0.23861432 -0.24009913 -0.32968932 -0.604869   -0.5445837 ]]
# Episode: 237/400, Epsilon:0.29, Average reward: -237.7
# Prediction for [500,0,500,0] is: [[-0.23973821 -0.2411066  -0.33066815 -0.6071193  -0.5465716 ]]
# Episode: 238/400, Epsilon:0.29, Average reward: -95.21
# Prediction for [500,0,500,0] is: [[-0.24085669 -0.24218269 -0.3316763  -0.60928994 -0.54850936]]
# Episode: 239/400, Epsilon:0.28, Average reward: -39.68
# Prediction for [500,0,500,0] is: [[-0.24198703 -0.24316855 -0.33268178 -0.6114325  -0.55047023]]
# Episode: 240/400, Epsilon:0.28, Average reward: -64.33
# Prediction for [500,0,500,0] is: [[-0.24304223 -0.24412142 -0.3337985  -0.61349213 -0.5524315 ]]
# Weights succesfully copied to Target model.
# Episode: 241/400, Epsilon:0.28, Average reward: -46.35
# Prediction for [500,0,500,0] is: [[-0.24416044 -0.24503154 -0.33488125 -0.615511   -0.55442524]]
# Episode: 242/400, Epsilon:0.28, Average reward: -58.65
# Prediction for [500,0,500,0] is: [[-0.2452823  -0.24600871 -0.33605754 -0.6174624  -0.55631465]]
# Episode: 243/400, Epsilon:0.27, Average reward: -45.07
# Prediction for [500,0,500,0] is: [[-0.24639083 -0.2469247  -0.3372324  -0.61948895 -0.55828524]]
# Episode: 244/400, Epsilon:0.27, Average reward: -39.99
# Prediction for [500,0,500,0] is: [[-0.24756625 -0.24788328 -0.33838862 -0.62144613 -0.5603429 ]]
# Episode: 245/400, Epsilon:0.27, Average reward: -188.96
# Prediction for [500,0,500,0] is: [[-0.24873261 -0.24879543 -0.33946598 -0.62359226 -0.56237495]]
# Weights succesfully copied to Target model.
# Episode: 246/400, Epsilon:0.26, Average reward: -64.67
# Prediction for [500,0,500,0] is: [[-0.2498961  -0.24979754 -0.34049612 -0.6256975  -0.5644053 ]]
# Episode: 247/400, Epsilon:0.26, Average reward: -32.56
# Prediction for [500,0,500,0] is: [[-0.25105146 -0.25073534 -0.34160888 -0.6277972  -0.5666884 ]]
# Episode: 248/400, Epsilon:0.26, Average reward: -59.72
# Prediction for [500,0,500,0] is: [[-0.25217003 -0.25170043 -0.34272075 -0.6298873  -0.56888366]]
# Episode: 249/400, Epsilon:0.25, Average reward: -46.1
# Prediction for [500,0,500,0] is: [[-0.25335342 -0.25264114 -0.34387714 -0.6319336  -0.5710332 ]]
# Episode: 250/400, Epsilon:0.25, Average reward: -63.92
# Prediction for [500,0,500,0] is: [[-0.2545554  -0.25363484 -0.34511274 -0.63402313 -0.57318246]]
# Weights succesfully copied to Target model.
# Episode: 251/400, Epsilon:0.25, Average reward: -63.88
# Prediction for [500,0,500,0] is: [[-0.2556923  -0.25460374 -0.34628534 -0.6361495  -0.57551897]]
# Episode: 252/400, Epsilon:0.25, Average reward: -84.16
# Prediction for [500,0,500,0] is: [[-0.2568127  -0.25561708 -0.3474609  -0.63821554 -0.5777462 ]]
# Episode: 253/400, Epsilon:0.24, Average reward: -102.78
# Prediction for [500,0,500,0] is: [[-0.25798002 -0.25657588 -0.34864664 -0.64019084 -0.57972014]]
# Episode: 254/400, Epsilon:0.24, Average reward: -75.07
# Prediction for [500,0,500,0] is: [[-0.2591837  -0.25762182 -0.34968022 -0.6423506  -0.5816587 ]]
# Episode: 255/400, Epsilon:0.24, Average reward: -88.56
# Prediction for [500,0,500,0] is: [[-0.26041347 -0.25871223 -0.35068503 -0.6444526  -0.5835326 ]]
# Weights succesfully copied to Target model.
# Episode: 256/400, Epsilon:0.23, Average reward: -78.22
# Prediction for [500,0,500,0] is: [[-0.2616886  -0.25974864 -0.35165897 -0.64665735 -0.5853214 ]]
# Episode: 257/400, Epsilon:0.23, Average reward: -88.23
# Prediction for [500,0,500,0] is: [[-0.26291254 -0.26082104 -0.35262543 -0.64893794 -0.5871186 ]]
# Episode: 258/400, Epsilon:0.23, Average reward: -84.53
# Prediction for [500,0,500,0] is: [[-0.2640838  -0.26193058 -0.35348564 -0.6511085  -0.5888762 ]]
# Episode: 259/400, Epsilon:0.22, Average reward: -102.4
# Prediction for [500,0,500,0] is: [[-0.26524895 -0.26307523 -0.3543564  -0.65314865 -0.59067726]]
# Episode: 260/400, Epsilon:0.22, Average reward: -43.42
# Prediction for [500,0,500,0] is: [[-0.2664023  -0.2642529  -0.35532397 -0.6551472  -0.5925904 ]]
# Weights succesfully copied to Target model.
# Episode: 261/400, Epsilon:0.22, Average reward: -306.59
# Prediction for [500,0,500,0] is: [[-0.26758358 -0.2654555  -0.35631275 -0.65706635 -0.5944193 ]]
# Episode: 262/400, Epsilon:0.22, Average reward: -248.91
# Prediction for [500,0,500,0] is: [[-0.2687673  -0.26650977 -0.3572573  -0.65911436 -0.5966324 ]]
# Episode: 263/400, Epsilon:0.21, Average reward: -401.28
# Prediction for [500,0,500,0] is: [[-0.26998046 -0.26751408 -0.35822794 -0.66125107 -0.5988816 ]]
# Episode: 264/400, Epsilon:0.21, Average reward: -62.0
# Prediction for [500,0,500,0] is: [[-0.27119946 -0.26853502 -0.35923982 -0.66341203 -0.6012775 ]]
# Episode: 265/400, Epsilon:0.21, Average reward: -110.56
# Prediction for [500,0,500,0] is: [[-0.27235663 -0.26952285 -0.36030698 -0.6655762  -0.60364366]]
# Weights succesfully copied to Target model.
# Episode: 266/400, Epsilon:0.2, Average reward: -49.12
# Prediction for [500,0,500,0] is: [[-0.27347386 -0.27056518 -0.36130357 -0.6678637  -0.60589373]]
# Episode: 267/400, Epsilon:0.2, Average reward: -37.93
# Prediction for [500,0,500,0] is: [[-0.27454406 -0.27166256 -0.3622706  -0.67028904 -0.6080886 ]]
# Episode: 268/400, Epsilon:0.2, Average reward: -42.83
# Prediction for [500,0,500,0] is: [[-0.2755518  -0.27279904 -0.363214   -0.6729349  -0.6100615 ]]
# Episode: 269/400, Epsilon:0.19, Average reward: -39.07
# Prediction for [500,0,500,0] is: [[-0.2765407 -0.2738412 -0.3643205 -0.6755495 -0.6121526]]
# Episode: 270/400, Epsilon:0.19, Average reward: -61.58
# Prediction for [500,0,500,0] is: [[-0.27758065 -0.2748614  -0.36552048 -0.6780808  -0.6140417 ]]
# Weights succesfully copied to Target model.
# Episode: 271/400, Epsilon:0.19, Average reward: -47.05
# Prediction for [500,0,500,0] is: [[-0.27871716 -0.27584687 -0.36664304 -0.68050987 -0.61584216]]
# Episode: 272/400, Epsilon:0.19, Average reward: -50.92
# Prediction for [500,0,500,0] is: [[-0.27992764 -0.2768709  -0.3678053  -0.682829   -0.6175296 ]]
# Episode: 273/400, Epsilon:0.18, Average reward: -40.0
# Prediction for [500,0,500,0] is: [[-0.2811767  -0.2780104  -0.36894456 -0.68487686 -0.6192147 ]]
# Episode: 274/400, Epsilon:0.18, Average reward: -55.12
# Prediction for [500,0,500,0] is: [[-0.2823838  -0.27913827 -0.37006646 -0.68710566 -0.6210536 ]]
# Episode: 275/400, Epsilon:0.18, Average reward: -54.64
# Prediction for [500,0,500,0] is: [[-0.28351203 -0.28025487 -0.3711722  -0.68923444 -0.6230108 ]]
# Weights succesfully copied to Target model.
# Episode: 276/400, Epsilon:0.17, Average reward: -56.2
# Prediction for [500,0,500,0] is: [[-0.28463295 -0.28138775 -0.3722731  -0.69152904 -0.6251022 ]]
# Episode: 277/400, Epsilon:0.17, Average reward: -310.56
# Prediction for [500,0,500,0] is: [[-0.2857749  -0.28252137 -0.37329698 -0.6939179  -0.6274341 ]]
# ...
# Prediction for [500,0,500,0] is: [[-0.31690785 -0.31967354 -0.40168273 -0.75488687 -0.6807031 ]]
# Episode: 307/400, Epsilon:0.08, Average reward: -48.75
# Prediction for [500,0,500,0] is: [[-0.3180587  -0.32083476 -0.4024186  -0.7568966  -0.6828624 ]]
# Episode: 308/400, Epsilon:0.08, Average reward: -61.65
# Prediction for [500,0,500,0] is: [[-0.31921676 -0.32197416 -0.4031501  -0.7588248  -0.6851857 ]]
# Episode: 309/400, Epsilon:0.07, Average reward: -85.74
# Prediction for [500,0,500,0] is: [[-0.32035267 -0.3230403  -0.40385377 -0.76076704 -0.6876695 ]]
# Episode: 310/400, Epsilon:0.07, Average reward: -35.0
# Prediction for [500,0,500,0] is: [[-0.32145578 -0.32415536 -0.40453282 -0.76267165 -0.6901402 ]]
# Weights succesfully copied to Target model.
# Episode: 311/400, Epsilon:0.07, Average reward: -35.65
# Prediction for [500,0,500,0] is: [[-0.3226027  -0.3252754  -0.40513235 -0.7646425  -0.6924772 ]]
# Episode: 312/400, Epsilon:0.07, Average reward: -66.86
# Prediction for [500,0,500,0] is: [[-0.3238396  -0.32633322 -0.40580612 -0.76653486 -0.6947926 ]]
# Episode: 313/400, Epsilon:0.06, Average reward: -53.47
# Prediction for [500,0,500,0] is: [[-0.32507443 -0.32736927 -0.40653858 -0.7686107  -0.6970124 ]]
# Episode: 314/400, Epsilon:0.06, Average reward: -57.6
# Prediction for [500,0,500,0] is: [[-0.32631782 -0.32833952 -0.40737158 -0.7706349  -0.6991552 ]]
# Episode: 315/400, Epsilon:0.06, Average reward: -53.48
# Prediction for [500,0,500,0] is: [[-0.32754734 -0.32933235 -0.40814963 -0.77268505 -0.70119166]]
# Weights succesfully copied to Target model.
# Episode: 316/400, Epsilon:0.05, Average reward: -45.11
# Prediction for [500,0,500,0] is: [[-0.32878298 -0.330365   -0.4088626  -0.7745434  -0.7031741 ]]
# Episode: 317/400, Epsilon:0.05, Average reward: -51.01
# Prediction for [500,0,500,0] is: [[-0.33001155 -0.3313449  -0.40951723 -0.77657205 -0.705108  ]]
# Episode: 318/400, Epsilon:0.05, Average reward: -41.89
# Prediction for [500,0,500,0] is: [[-0.331177   -0.33230346 -0.41016942 -0.77866316 -0.7069009 ]]
# Episode: 319/400, Epsilon:0.04, Average reward: -52.17
# Prediction for [500,0,500,0] is: [[-0.3323108  -0.33329946 -0.41088444 -0.78056335 -0.7085768 ]]
# Episode: 320/400, Epsilon:0.04, Average reward: -33.23
# Prediction for [500,0,500,0] is: [[-0.33337748 -0.33427945 -0.41176528 -0.78243166 -0.7102183 ]]
# Weights succesfully copied to Target model.
# Episode: 321/400, Epsilon:0.04, Average reward: -57.9
# Prediction for [500,0,500,0] is: [[-0.33442777 -0.33520305 -0.41256553 -0.7844846  -0.7119578 ]]
# Episode: 322/400, Epsilon:0.04, Average reward: -66.96
# Prediction for [500,0,500,0] is: [[-0.3354869  -0.33604807 -0.41348243 -0.78644466 -0.7137526 ]]
# Episode: 323/400, Epsilon:0.03, Average reward: -23.06
# Prediction for [500,0,500,0] is: [[-0.33657825 -0.33690366 -0.41433784 -0.7884249  -0.715579  ]]
# New best agent found. Saved in C:\Users\acabrejasegea\OneDrive - The Alan Turing Institute\Desktop\ATI\0_TMF\MLforFlowOptimisation\Vissim\Single_Cross_Straight\Single_Cross_Straight_Episodes400_ProgramDuelingDDQN_BestAgent0_Memory.p
# Episode: 324/400, Epsilon:0.03, Average reward: -94.78
# Prediction for [500,0,500,0] is: [[-0.33764172 -0.33778226 -0.41510624 -0.79057467 -0.71737814]]
# Episode: 325/400, Epsilon:0.03, Average reward: -87.7
# Prediction for [500,0,500,0] is: [[-0.33873615 -0.3387081  -0.41580087 -0.79265547 -0.71917045]]
# Weights succesfully copied to Target model.
# Episode: 326/400, Epsilon:0.02, Average reward: -43.42
# Prediction for [500,0,500,0] is: [[-0.3398946  -0.33969384 -0.41650364 -0.79448426 -0.7209449 ]]
# Episode: 327/400, Epsilon:0.02, Average reward: -45.63
# Prediction for [500,0,500,0] is: [[-0.34103587 -0.34068936 -0.41710997 -0.79638326 -0.7227463 ]]
# Episode: 328/400, Epsilon:0.02, Average reward: -53.28
# Prediction for [500,0,500,0] is: [[-0.34214422 -0.34170485 -0.41774502 -0.79825765 -0.7244457 ]]
# Episode: 329/400, Epsilon:0.01, Average reward: -73.76
# Prediction for [500,0,500,0] is: [[-0.34330302 -0.3426321  -0.41842803 -0.8000531  -0.72625196]]
# Episode: 330/400, Epsilon:0.01, Average reward: -53.99
# Prediction for [500,0,500,0] is: [[-0.34453797 -0.34355232 -0.41902474 -0.80182946 -0.72795814]]
# Weights succesfully copied to Target model.
# Episode: 331/400, Epsilon:0.01, Average reward: -43.16
# Prediction for [500,0,500,0] is: [[-0.34569776 -0.34442937 -0.41969702 -0.8037009  -0.72978747]]
# Episode: 332/400, Epsilon:0.01, Average reward: -72.07
# Prediction for [500,0,500,0] is: [[-0.34685576 -0.34525877 -0.42034477 -0.805495   -0.7316686 ]]
# Episode: 333/400, Epsilon:0.0, Average reward: -49.62
# Prediction for [500,0,500,0] is: [[-0.34804374 -0.3460762  -0.42091727 -0.8072158  -0.73372155]]
# Episode: 334/400, Epsilon:-0.0, Average reward: -54.29
# Prediction for [500,0,500,0] is: [[-0.34926677 -0.3468873  -0.42145863 -0.80898476 -0.7357903 ]]
# Episode: 335/400, Epsilon:-0.0, Average reward: -40.58
# Prediction for [500,0,500,0] is: [[-0.3504612  -0.3476912  -0.42201972 -0.81077886 -0.7377999 ]]
# Weights succesfully copied to Target model.
# Episode: 336/400, Epsilon:-0.0, Average reward: -90.53
# Prediction for [500,0,500,0] is: [[-0.35161322 -0.3485347  -0.4225287  -0.81248486 -0.73963   ]]
# Episode: 337/400, Epsilon:-0.0, Average reward: -76.81
# Prediction for [500,0,500,0] is: [[-0.35282183 -0.34944534 -0.4230004  -0.81409144 -0.7412901 ]]
# Episode: 338/400, Epsilon:-0.0, Average reward: -47.01
# Prediction for [500,0,500,0] is: [[-0.35411212 -0.35031164 -0.42338473 -0.81578934 -0.74317807]]
# Episode: 339/400, Epsilon:-0.0, Average reward: -47.96
# Prediction for [500,0,500,0] is: [[-0.35531655 -0.35118884 -0.42383972 -0.8173927  -0.745141  ]]
# Episode: 340/400, Epsilon:-0.0, Average reward: -53.6
# Prediction for [500,0,500,0] is: [[-0.3564136  -0.3520506  -0.4243551  -0.8190421  -0.74700356]]
# Weights succesfully copied to Target model.
# Episode: 341/400, Epsilon:-0.0, Average reward: -86.71
# Prediction for [500,0,500,0] is: [[-0.35746026 -0.3529133  -0.42488015 -0.82074416 -0.7488359 ]]
# Episode: 342/400, Epsilon:-0.0, Average reward: -61.99
# Prediction for [500,0,500,0] is: [[-0.35851526 -0.35375428 -0.4253838  -0.82240653 -0.7506455 ]]
# Episode: 343/400, Epsilon:-0.0, Average reward: -27.64
# Prediction for [500,0,500,0] is: [[-0.35961664 -0.3546537  -0.42587996 -0.82418746 -0.75233734]]
# Episode: 344/400, Epsilon:-0.0, Average reward: -59.27
# Prediction for [500,0,500,0] is: [[-0.36075717 -0.35556173 -0.42632973 -0.82593894 -0.75417256]]
# Episode: 345/400, Epsilon:-0.0, Average reward: -50.96
# Prediction for [500,0,500,0] is: [[-0.36192217 -0.35654455 -0.4267993  -0.82761353 -0.7560601 ]]
# Weights succesfully copied to Target model.
# Episode: 346/400, Epsilon:-0.0, Average reward: -40.63
# Prediction for [500,0,500,0] is: [[-0.363124   -0.3574909  -0.4272381  -0.8292448  -0.75801635]]
# Episode: 347/400, Epsilon:-0.0, Average reward: -85.98
# Prediction for [500,0,500,0] is: [[-0.36429077 -0.3585198  -0.4276542  -0.83098954 -0.75985867]]
# Episode: 348/400, Epsilon:-0.0, Average reward: -84.05
# Prediction for [500,0,500,0] is: [[-0.36544806 -0.35950473 -0.4280854  -0.83277917 -0.7616302 ]]
# Episode: 349/400, Epsilon:-0.0, Average reward: -106.3
# Prediction for [500,0,500,0] is: [[-0.3665831  -0.36041698 -0.42848343 -0.8345419  -0.7634978 ]]
# Episode: 350/400, Epsilon:-0.0, Average reward: -41.52
# Prediction for [500,0,500,0] is: [[-0.36766738 -0.3613368  -0.4288778  -0.8364465  -0.7653254 ]]
# Weights succesfully copied to Target model.
# Episode: 351/400, Epsilon:-0.0, Average reward: -59.85
# Prediction for [500,0,500,0] is: [[-0.36876005 -0.3622946  -0.4292544  -0.83835506 -0.767197  ]]
# Episode: 352/400, Epsilon:-0.0, Average reward: -52.28
# Prediction for [500,0,500,0] is: [[-0.36990342 -0.36325425 -0.42966875 -0.84000313 -0.7689322 ]]
# Episode: 353/400, Epsilon:-0.0, Average reward: -29.17
# Prediction for [500,0,500,0] is: [[-0.37103122 -0.36418808 -0.43011242 -0.8416244  -0.7708307 ]]
# Episode: 354/400, Epsilon:-0.0, Average reward: -65.65
# Prediction for [500,0,500,0] is: [[-0.3721107  -0.3651108  -0.43054307 -0.8432988  -0.77261364]]
# Episode: 355/400, Epsilon:-0.0, Average reward: -88.41
# Prediction for [500,0,500,0] is: [[-0.37321216 -0.36615065 -0.43100506 -0.84490776 -0.77422625]]
# Weights succesfully copied to Target model.
# Episode: 356/400, Epsilon:-0.0, Average reward: -43.3
# Prediction for [500,0,500,0] is: [[-0.3742651  -0.36724582 -0.43148035 -0.8463669  -0.77572894]]
# Episode: 357/400, Epsilon:-0.0, Average reward: -40.82
# Prediction for [500,0,500,0] is: [[-0.37535155 -0.3683663  -0.4320193  -0.8479364  -0.7772313 ]]
# Episode: 358/400, Epsilon:-0.0, Average reward: -88.79
# Prediction for [500,0,500,0] is: [[-0.37645563 -0.36948878 -0.43252164 -0.8495371  -0.77891845]]
# Episode: 359/400, Epsilon:-0.0, Average reward: -62.65
# Prediction for [500,0,500,0] is: [[-0.37755263 -0.37056845 -0.43301672 -0.85114676 -0.78065324]]
# Episode: 360/400, Epsilon:-0.0, Average reward: -80.34
# Prediction for [500,0,500,0] is: [[-0.37861025 -0.37166154 -0.43347478 -0.8528054  -0.7823162 ]]
# Weights succesfully copied to Target model.
# Episode: 361/400, Epsilon:-0.0, Average reward: -43.11
# Prediction for [500,0,500,0] is: [[-0.37966263 -0.37277624 -0.43390042 -0.8545456  -0.78389466]]
# Episode: 362/400, Epsilon:-0.0, Average reward: -44.25
# Prediction for [500,0,500,0] is: [[-0.38070756 -0.37382525 -0.43432063 -0.85625005 -0.785567  ]]
# Episode: 363/400, Epsilon:-0.0, Average reward: -56.03
# Prediction for [500,0,500,0] is: [[-0.38174492 -0.37495235 -0.43474567 -0.85780525 -0.78722274]]
# Episode: 364/400, Epsilon:-0.0, Average reward: -58.47
# Prediction for [500,0,500,0] is: [[-0.38276207 -0.3761174  -0.43513885 -0.8593815  -0.7888855 ]]
# Episode: 365/400, Epsilon:-0.0, Average reward: -55.08
# Prediction for [500,0,500,0] is: [[-0.3837738  -0.37733662 -0.43552387 -0.8610345  -0.7904531 ]]
# Weights succesfully copied to Target model.
# Episode: 366/400, Epsilon:-0.0, Average reward: -35.94
# Prediction for [500,0,500,0] is: [[-0.38480788 -0.37852192 -0.43588543 -0.86257416 -0.7919904 ]]
# Episode: 367/400, Epsilon:-0.0, Average reward: -48.82
# Prediction for [500,0,500,0] is: [[-0.38584477 -0.37969857 -0.43626755 -0.86401355 -0.79352266]]
# Episode: 368/400, Epsilon:-0.0, Average reward: -70.37
# Prediction for [500,0,500,0] is: [[-0.38685638 -0.3808549  -0.43674195 -0.8655106  -0.79517126]]
# Episode: 369/400, Epsilon:-0.0, Average reward: -56.91
# Prediction for [500,0,500,0] is: [[-0.3878926  -0.38196957 -0.43726757 -0.8670403  -0.7967553 ]]
# Episode: 370/400, Epsilon:-0.0, Average reward: -46.67
# Prediction for [500,0,500,0] is: [[-0.388902   -0.3831262  -0.43786356 -0.8685519  -0.7983799 ]]
# Weights succesfully copied to Target model.
# Episode: 371/400, Epsilon:-0.0, Average reward: -49.44
# Prediction for [500,0,500,0] is: [[-0.38995957 -0.38439023 -0.43848324 -0.86987853 -0.7998048 ]]
# Episode: 372/400, Epsilon:-0.0, Average reward: -43.01
# Prediction for [500,0,500,0] is: [[-0.3909916  -0.38563323 -0.43913442 -0.87103134 -0.80119926]]
# Episode: 373/400, Epsilon:-0.0, Average reward: -33.21
# Prediction for [500,0,500,0] is: [[-0.39202034 -0.38691044 -0.4398177  -0.87206805 -0.80249965]]
# Episode: 374/400, Epsilon:-0.0, Average reward: -52.62
# Prediction for [500,0,500,0] is: [[-0.39312553 -0.3882103  -0.44044188 -0.8731035  -0.803681  ]]
# Episode: 375/400, Epsilon:-0.0, Average reward: -37.85
# Prediction for [500,0,500,0] is: [[-0.3942164  -0.38945565 -0.4410263  -0.8742049  -0.8048217 ]]
# Weights succesfully copied to Target model.
# Episode: 376/400, Epsilon:-0.0, Average reward: -42.83
# Prediction for [500,0,500,0] is: [[-0.39529473 -0.39069426 -0.4416405  -0.87523127 -0.8059467 ]]
# Episode: 377/400, Epsilon:-0.0, Average reward: -46.88
# Prediction for [500,0,500,0] is: [[-0.39641273 -0.39197984 -0.4421656  -0.8762281  -0.80702823]]
# Episode: 378/400, Epsilon:-0.0, Average reward: -76.81
# Prediction for [500,0,500,0] is: [[-0.39757133 -0.39330453 -0.44264817 -0.8774021  -0.808152  ]]
# Episode: 379/400, Epsilon:-0.0, Average reward: -38.62
# Prediction for [500,0,500,0] is: [[-0.3987761  -0.39460316 -0.44306558 -0.8785369  -0.8091506 ]]
# Episode: 380/400, Epsilon:-0.0, Average reward: -71.66
# Prediction for [500,0,500,0] is: [[-0.39994264 -0.39591473 -0.4434533  -0.8798033  -0.8101691 ]]
# Weights succesfully copied to Target model.
# Episode: 381/400, Epsilon:-0.0, Average reward: -63.64
# Prediction for [500,0,500,0] is: [[-0.40111881 -0.3972403  -0.44382346 -0.8810159  -0.8110732 ]]
# Episode: 382/400, Epsilon:-0.0, Average reward: -44.47
# Prediction for [500,0,500,0] is: [[-0.40226874 -0.3985731  -0.44416392 -0.8822438  -0.81200653]]
# Episode: 383/400, Epsilon:-0.0, Average reward: -34.38
# Prediction for [500,0,500,0] is: [[-0.40339363 -0.39988536 -0.44447565 -0.8835139  -0.8128951 ]]
# Episode: 384/400, Epsilon:-0.0, Average reward: -65.88
# Prediction for [500,0,500,0] is: [[-0.40454954 -0.4011839  -0.4447559  -0.8848131  -0.81371933]]
# Episode: 385/400, Epsilon:-0.0, Average reward: -66.26
# Prediction for [500,0,500,0] is: [[-0.4057306  -0.40246767 -0.44507015 -0.88615465 -0.81458247]]
# Weights succesfully copied to Target model.
# Episode: 386/400, Epsilon:-0.0, Average reward: -51.05
# Prediction for [500,0,500,0] is: [[-0.40690485 -0.4037322  -0.44543666 -0.88745344 -0.8153842 ]]
# Episode: 387/400, Epsilon:-0.0, Average reward: -45.89
# Prediction for [500,0,500,0] is: [[-0.40803224 -0.40501487 -0.4458072  -0.88865566 -0.81619084]]
# Episode: 388/400, Epsilon:-0.0, Average reward: -56.85
# Prediction for [500,0,500,0] is: [[-0.409132   -0.40630072 -0.4461493  -0.8898562  -0.8170868 ]]
# Episode: 389/400, Epsilon:-0.0, Average reward: -42.2
# Prediction for [500,0,500,0] is: [[-0.41019702 -0.4075771  -0.44649774 -0.8912444  -0.81796813]]
# Episode: 390/400, Epsilon:-0.0, Average reward: -55.85
# Prediction for [500,0,500,0] is: [[-0.4112131  -0.40886647 -0.44681484 -0.8926263  -0.81896925]]
# Weights succesfully copied to Target model.
# Episode: 391/400, Epsilon:-0.0, Average reward: -38.37
# Prediction for [500,0,500,0] is: [[-0.4122833  -0.41015366 -0.44714993 -0.89399874 -0.81999195]]
# Episode: 392/400, Epsilon:-0.0, Average reward: -89.19
# Prediction for [500,0,500,0] is: [[-0.41339236 -0.41149247 -0.44748455 -0.89532036 -0.82111603]]
# Episode: 393/400, Epsilon:-0.0, Average reward: -66.6
# Prediction for [500,0,500,0] is: [[-0.4144853  -0.4129086  -0.44793123 -0.8965857  -0.8221616 ]]
# Episode: 394/400, Epsilon:-0.0, Average reward: -42.07
# Prediction for [500,0,500,0] is: [[-0.41555804 -0.41435274 -0.44839513 -0.8977591  -0.8231167 ]]
# Episode: 395/400, Epsilon:-0.0, Average reward: -45.22
# Prediction for [500,0,500,0] is: [[-0.41662064 -0.41586235 -0.4488834  -0.8990151  -0.8241497 ]]
# Weights succesfully copied to Target model.
# Episode: 396/400, Epsilon:-0.0, Average reward: -37.52
# Prediction for [500,0,500,0] is: [[-0.41773432 -0.41730067 -0.44931823 -0.9002635  -0.825338  ]]
# Episode: 397/400, Epsilon:-0.0, Average reward: -63.23
# Prediction for [500,0,500,0] is: [[-0.41884983 -0.41877007 -0.44977513 -0.90135765 -0.82646716]]
# Episode: 398/400, Epsilon:-0.0, Average reward: -78.23
# Prediction for [500,0,500,0] is: [[-0.4199639  -0.42025864 -0.4502315  -0.9024827  -0.8275355 ]]
# Episode: 399/400, Epsilon:-0.0, Average reward: -35.56
# Prediction for [500,0,500,0] is: [[-0.4210689  -0.42170995 -0.450714   -0.9034806  -0.8284755 ]]
# Episode: 400/400, Epsilon:-0.0, Average reward: -58.13
# Prediction for [500,0,500,0] is: [[-0.42219484 -0.42315257 -0.45118898 -0.9044163  -0.8293647 ]]
# Weights succesfully copied to Target model.
# Saving architecture, weights and optimizer state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Saved Partial results at the end of episode 400.
# Saving architecture, weights and optimizer state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Model, architecture, weights, optimizer, memory and training results succesfully saved. Succesfully Terminated.

# %%
# Plotting training progress
plt.figure(figsize=(8,4.5))
x_series = range(1,len(reward_storage)+1)
fit = np.polyfit(x_series,reward_storage,1)
fit_fn = np.poly1d(fit) 
plt.plot(x_series,reward_storage, '-b', x_series, fit_fn(x_series), '--r')
plt.xlabel('Episodes')
plt.ylabel('Average agent reward in episode')
plt.title('Training evolution and trend')
plt.gca().legend(('Episode Reward','Linear Trend'))
plt.show()

# Plotting training loss
plt.figure(figsize=(8,4.5))
x_series = range(1,len(Agents[0].loss)+1)
plt.plot(x_series,Agents[0].loss, '-b')
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.gca().legend(('Loss'))
plt.show()

# %%
np.linspace(1,episodes,episodes).shape

# %%
import matplotlib.pyplot as plt

# Start reward plot
rew,axr = plt.subplots(1,1)
axr.set_xlabel('Episodes')
axr.set_ylabel('Average agent reward in episode')
axr.set_xlim(0,400)
axr.set_ylim(-500,0)
pltlive(reward_storage, 400,rew, axr, ['r'])

# %%
fig,axr = plt.subplots(1,1)

# %%
loss_plot[1] = Agents[0].loss[-1]

# %%
Agents[0].loss[-1][0]
