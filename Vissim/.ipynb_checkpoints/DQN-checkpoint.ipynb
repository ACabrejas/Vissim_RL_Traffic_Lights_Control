# %% [markdown]
# # Reinforcement Learning (DQN) - Cartpole Task
#
# * The goal is for agent to learn keep the pole attached to a cart upright as long as possible. The agent does so by choosing between two actions: 'move the cart left or right'.
#
# * In reinforcement learning the agent learns how to act or take action by trail and error. In other words, by trying out and action and receving a feedback/reward. It uses the feedback/reward to learn if taking an action in a particular senario (state) was good or bad. The model aim to maximise the total accumulated reward.
#
# * Current version just uses CPU.

# %% [markdown]
# ### imports

# %%
import random
import gym
import numpy as np
from time import time
from keras.callbacks import TensorBoard
from collections import deque, namedtuple
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Multiply, Dropout
from keras.optimizers import Adam
from keras import backend as K

import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-5df16bb94776> in <module>()
#       3 import numpy as np
#       4 from time import time
# ----> 5 from keras.callbacks import TensorBoard
#       6 from collections import deque, namedtuple
#       7 from keras.models import Sequential, Model
#
# C:\Users\acabrejasegea\AppData\Local\Continuum\anaconda3\envs\vissim\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\Users\acabrejasegea\AppData\Local\Continuum\anaconda3\envs\vissim\lib\site-packages\keras\utils\__init__.py in <module>()
#       1 from __future__ import absolute_import
# ----> 2 from . import np_utils
#       3 from . import generic_utils
#       4 from . import data_utils
#       5 from . import io_utils
#
# ImportError: cannot import name np_utils

# %% [markdown]
# ### Hyperparameters

# %%
BATCH_SIZE = 64
GAMMA = 0.99
EPS_START = 1.0
EPS_END = 0.01
EPS_DECAY = 0.99
TARGET_UPDATE = 100
LEARNING_RATE = 0.001
EPISODES = 100

# %% [markdown]
# ### MDP transition represented as a named tuple

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward', 'done'))

# %% [markdown]
# ### Replay memory (a database to store input data and to sample from to create a training batch)

# %%
class ReplayMemory(object):
    def __init__(self, capacity=10000):
        self.memory = deque(maxlen = capacity)
        
    def add(self, *args):
        self.memory.append(Transition(*args))
    
    def sample(self, batch_size=10):
        return random.sample(self.memory, batch_size)
    
    def get_memory(self):
        return self.memory
    
    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ### Define Huber Loss Function.

# %%
def _huber_loss(y_true, y_pred, clip_delta=1.0):
    error = y_true - y_pred
    cond  = K.abs(error) <= clip_delta
    squared_loss = 0.5 * K.square(error)
    quadratic_loss = 0.5 * K.square(clip_delta) + clip_delta * (K.abs(error) - clip_delta)
    return K.mean(tf.where(cond, squared_loss, quadratic_loss))

# %% [markdown]
# ### Q-network

# %%
class Network(object):
    def __init__(self, state_size, action_size):

        # create the neural network.
        states_input = Input((state_size,), name='states')
        actions_input = Input((action_size,), name='mask')

        fc1 = Dense(24, activation='tanh')(states_input)
        #dropout_1 = Dropout(0.2)(fc1)
        fc2 = Dense(24, activation='tanh')(fc1)
        #dropout_2 = Dropout(0.2)(fc2)
        out = Dense(action_size, activation='linear')(fc2)
        filtered_output = Multiply()([out, actions_input])
        self.model = Model(inputs=[states_input, actions_input], outputs=filtered_output)
        self.model.compile(loss=_huber_loss,optimizer=Adam(lr=LEARNING_RATE, clipnorm=1.))
    
    def get_model(self):
        return self.model
        

#Test
net = Network(4, 2)
model = net.get_model()
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# states (InputLayer)             (None, 4)            0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           250         states[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 50)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            102         dropout_1[0][0]
# __________________________________________________________________________________________________
# mask (InputLayer)               (None, 2)            0
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 2)            0           dense_2[0][0]
#                                                                  mask[0][0]
# ==================================================================================================
# Total params: 352
# Trainable params: 352
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
class DQN(object):
    def __init__(self):
        self.env = gym.make('CartPole-v1')
        self.state_size = self.env.observation_space.shape[0]
        #self.tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
        self.action_size = self.env.action_space.n
        self.network = Network(self.state_size, self.action_size)
        self.target_net = Network(self.state_size, self.action_size)
        self.memory = ReplayMemory()
        self.steps = 0
        self.epsilon = EPS_START
        self.duration = [0] * 100

    def update_target_model(self):
        # copy weights from model to target_model
        self.target_net.get_model().set_weights(self.network.get_model().get_weights())
        
    def select_action(self, state):
        if self.epsilon > EPS_END:
            self.epsilon *= EPS_DECAY        
        self.steps += 1
        #Epsilon greedy exploration/exploitation.
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.network.get_model().predict([state, np.ones((1,2))])
        return np.argmax(act_values[0])
    
    def exploit_action(self, state):
        act_values = self.network.get_model().predict([state, np.ones((1,2))])
        return np.argmax(act_values[0])
    
    def train(self):
        
        #Check if we have generated enough data to train.
        if len(self.memory) < BATCH_SIZE:
            return
        
        #sample the minibatch to train network on.
        transitions = self.memory.sample(BATCH_SIZE)
        batch = Transition(*zip(*transitions))

        state_batch = np.asarray(batch.state).reshape(BATCH_SIZE,self.state_size)
        action_batch = np.asarray(batch.action).reshape(BATCH_SIZE,-1)
        reward_batch = np.asarray(batch.reward).reshape(BATCH_SIZE,-1)
        next_state_batch = np.asarray(batch.next_state).reshape(BATCH_SIZE,self.state_size)
        done_batch = np.asarray(batch.done).reshape(BATCH_SIZE,-1)
        
        #one hot encoding of action space.
        one_hot_targets = (np.eye(self.action_size)[action_batch]).reshape(BATCH_SIZE,-1)
        
        # Compute max V(s_{t+1}) for all next states.
        next_state_values = self.target_net.get_model().predict([next_state_batch, np.ones(one_hot_targets.shape)])
        
        # Compute the expected Q values
        end_multiplier = -(done_batch - 1) 
        expected_state_action_values = ((np.max(next_state_values, axis=1, keepdims=True) * GAMMA)*end_multiplier) + reward_batch
        # Fit the keras model.
        model.fit([state_batch, one_hot_targets], one_hot_targets * expected_state_action_values,
                   epochs=1, batch_size=BATCH_SIZE, verbose=1)
        #callbacks=[self.tensorboard]  
        
    def run(self, episode_no):
        #reset the environment to start a fresh trial.
        state = self.env.reset()
        state = np.reshape(state, [1, self.state_size])
        self.steps = 0
        total_reward = 0
        while True:
            action = self.select_action(state)
            next_state, reward, done, _ = self.env.step(action)
            next_state = np.reshape(next_state, [1, self.state_size])
            if done and self.steps < 195:
                reward = -100
            total_reward += reward
            #add transition to replay memory.
            self.memory.add(state, action, next_state, reward, done)
            
            # Move to the next state
            state = next_state
            
            if done:
                print("{2} Episode {0} finished after {1} steps  and with total reward {3}"
                      .format(episode_no, self.steps, '\033[92m' if self.steps >= 195 else '\033[99m',
                              total_reward))
                break
        self.duration[(episode_no%100)] = self.steps
        #train for mini batch.
        self.train()

        if episode_no % TARGET_UPDATE == 0:
            self.update_target_model()

    def test(self, number_of_episodes):
        for e in range(number_of_episodes):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size])
            t = 0
            total_reward = 0
            while True:
                t += 1
                self.env.render()
                action = self.exploit_action(state)
                next_state, reward, done, _ = self.env.step(action)
                total_reward += reward
                state = np.reshape(next_state, [1, self.state_size])
                if done:
                    break
            
            print("number of steps : " + str(t))
            print("total_reward : " + str(total_reward))
            
            
        
            
            
agent = DQN()

agent.update_target_model()

for i in range(500):
    agent.run(i)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
#  Episode 0 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7923
#  Episode 1 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5732
#  Episode 2 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0092
#  Episode 3 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7917
#  Episode 4 finished after 88 steps  and with total reward -13.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0050
#  Episode 5 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7875
#  Episode 6 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0028
#  Episode 7 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7900
#  Episode 8 finished after 49 steps  and with total reward -52.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7879
#  Episode 9 finished after 96 steps  and with total reward -5.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7872
#  Episode 10 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5799
#  Episode 11 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7898
#  Episode 12 finished after 86 steps  and with total reward -15.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7934
#  Episode 13 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7873
#  Episode 14 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7913
#  Episode 15 finished after 43 steps  and with total reward -58.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7883
#  Episode 16 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0037
#  Episode 17 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7929
#  Episode 18 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0039
#  Episode 19 finished after 98 steps  and with total reward -3.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7868
#  Episode 20 finished after 78 steps  and with total reward -23.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0043
#  Episode 21 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7915
#  Episode 22 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0051
#  Episode 23 finished after 89 steps  and with total reward -12.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7932
#  Episode 24 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0052
#  Episode 25 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0050
#  Episode 26 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0039
#  Episode 27 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 62us/step - loss: 0.7876
#  Episode 28 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7907
#  Episode 29 finished after 96 steps  and with total reward -5.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7864
#  Episode 30 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5639
#  Episode 31 finished after 94 steps  and with total reward -7.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7828
#  Episode 32 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7913
#  Episode 33 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0025
#  Episode 34 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7853
#  Episode 35 finished after 93 steps  and with total reward -8.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7921
#  Episode 36 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0033
#  Episode 37 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3557
#  Episode 38 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 62us/step - loss: 0.0022
#  Episode 39 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7875
#  Episode 40 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7897
#  Episode 41 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0022
#  Episode 42 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0029
#  Episode 43 finished after 100 steps  and with total reward -1.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7905
#  Episode 44 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5787
#  Episode 45 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0021
#  Episode 46 finished after 55 steps  and with total reward -46.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7903
#  Episode 47 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3640
#  Episode 48 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0040
#  Episode 49 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7834
#  Episode 50 finished after 91 steps  and with total reward -10.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5716
#  Episode 51 finished after 93 steps  and with total reward -8.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 52 finished after 88 steps  and with total reward -13.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0039
#  Episode 53 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0028
#  Episode 54 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0027
#  Episode 55 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0041
#  Episode 56 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0037
#  Episode 57 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5688
#  Episode 58 finished after 89 steps  and with total reward -12.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0026
#  Episode 59 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5769
#  Episode 60 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0049
#  Episode 61 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0026
#  Episode 62 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7926
#  Episode 63 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7924
#  Episode 64 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5702
#  Episode 65 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7932
#  Episode 66 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7842
#  Episode 67 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0049
#  Episode 68 finished after 78 steps  and with total reward -23.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7862
#  Episode 69 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7920
#  Episode 70 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0022
#  Episode 71 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5701
#  Episode 72 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7888
#  Episode 73 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7886
#  Episode 74 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5772
#  Episode 75 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 1.5720
#  Episode 76 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7906
#  Episode 77 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7843
#  Episode 78 finished after 94 steps  and with total reward -7.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0022
#  Episode 79 finished after 81 steps  and with total reward -20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0016
#  Episode 80 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7887
#  Episode 81 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0034
#  Episode 82 finished after 86 steps  and with total reward -15.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5697
#  Episode 83 finished after 48 steps  and with total reward -53.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7876
#  Episode 84 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7868
#  Episode 85 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 2.3515
#  Episode 86 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5691
#  Episode 87 finished after 55 steps  and with total reward -46.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 3.9327
#  Episode 88 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0024
#  Episode 89 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0038
#  Episode 90 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 62us/step - loss: 2.3579
#  Episode 91 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7872
#  Episode 92 finished after 53 steps  and with total reward -48.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7841
#  Episode 93 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3642
#  Episode 94 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0026
#  Episode 95 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 30us/step - loss: 0.7889
#  Episode 96 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7900
#  Episode 97 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7864
#  Episode 98 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0028
#  Episode 99 finished after 48 steps  and with total reward -53.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0038
#  Episode 100 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 1.5704
#  Episode 101 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0026
#  Episode 102 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5686
#  Episode 103 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7878
#  Episode 104 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0047
#  Episode 105 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0046
#  Episode 106 finished after 105 steps  and with total reward 4.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 107 finished after 56 steps  and with total reward -45.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7851
#  Episode 108 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0028
#  Episode 109 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7910
#  Episode 110 finished after 44 steps  and with total reward -57.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 1.5651
#  Episode 111 finished after 52 steps  and with total reward -49.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7892
#  Episode 112 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0032
#  Episode 113 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7839
#  Episode 114 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7868
#  Episode 115 finished after 91 steps  and with total reward -10.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0037
#  Episode 116 finished after 52 steps  and with total reward -49.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0029
#  Episode 117 finished after 53 steps  and with total reward -48.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7863
#  Episode 118 finished after 84 steps  and with total reward -17.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0018
#  Episode 119 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5715
#  Episode 120 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0022
#  Episode 121 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5634
#  Episode 122 finished after 93 steps  and with total reward -8.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0036
#  Episode 123 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 62us/step - loss: 0.7928
#  Episode 124 finished after 82 steps  and with total reward -19.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0017
#  Episode 125 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0027
#  Episode 126 finished after 55 steps  and with total reward -46.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7827
#  Episode 127 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7866
#  Episode 128 finished after 114 steps  and with total reward 13.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7823
#  Episode 129 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7892
#  Episode 130 finished after 49 steps  and with total reward -52.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0034
#  Episode 131 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5753
#  Episode 132 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5671
#  Episode 133 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7897
#  Episode 134 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7889
#  Episode 135 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0018
#  Episode 136 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0024
#  Episode 137 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0026
#  Episode 138 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3507
#  Episode 139 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 30us/step - loss: 0.0020
#  Episode 140 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7855
#  Episode 141 finished after 51 steps  and with total reward -50.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5708
#  Episode 142 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0020
#  Episode 143 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5686
#  Episode 144 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0025
#  Episode 145 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7893
#  Episode 146 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7821
#  Episode 147 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 1.5682
#  Episode 148 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0025
#  Episode 149 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7908
#  Episode 150 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3543
#  Episode 151 finished after 94 steps  and with total reward -7.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7872
#  Episode 152 finished after 86 steps  and with total reward -15.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0017
#  Episode 153 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7880
#  Episode 154 finished after 113 steps  and with total reward 12.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7821
#  Episode 155 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7881
#  Episode 156 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7845
#  Episode 157 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0031
#  Episode 158 finished after 81 steps  and with total reward -20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0027
#  Episode 159 finished after 55 steps  and with total reward -46.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5721
#  Episode 160 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 62us/step - loss: 0.7882
#  Episode 161 finished after 55 steps  and with total reward -46.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 162 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7913
#  Episode 163 finished after 90 steps  and with total reward -11.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5683
#  Episode 164 finished after 97 steps  and with total reward -4.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 165 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0014
#  Episode 166 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7852
#  Episode 167 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0023
#  Episode 168 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7893
#  Episode 169 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 2.3570
#  Episode 170 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 171 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0036
#  Episode 172 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 32us/step - loss: 0.7819
#  Episode 173 finished after 92 steps  and with total reward -9.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0015
#  Episode 174 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3599
#  Episode 175 finished after 52 steps  and with total reward -49.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0036
#  Episode 176 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0026
#  Episode 177 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0026
#  Episode 178 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0023
#  Episode 179 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7901
#  Episode 180 finished after 51 steps  and with total reward -50.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5724
#  Episode 181 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5668
#  Episode 182 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7849
#  Episode 183 finished after 78 steps  and with total reward -23.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7878
#  Episode 184 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5744
#  Episode 185 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0025
#  Episode 186 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5685
#  Episode 187 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 188 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3625
#  Episode 189 finished after 53 steps  and with total reward -48.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7844
#  Episode 190 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 63us/step - loss: 0.7921
#  Episode 191 finished after 56 steps  and with total reward -45.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0037
#  Episode 192 finished after 43 steps  and with total reward -58.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7901
#  Episode 193 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0028
#  Episode 194 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0021
#  Episode 195 finished after 41 steps  and with total reward -60.0
# Epoch 1/1
# 64/64 [==============================] - 0s 62us/step - loss: 0.7858
#  Episode 196 finished after 100 steps  and with total reward -1.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 1.5683
#  Episode 197 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0020
#  Episode 198 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7915
#  Episode 199 finished after 55 steps  and with total reward -46.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0025
#  Episode 200 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0023
#  Episode 201 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 62us/step - loss: 0.7886
#  Episode 202 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 1.5709
#  Episode 203 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7901
#  Episode 204 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0027
#  Episode 205 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0020
#  Episode 206 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 46us/step - loss: 0.0017
#  Episode 207 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0035
#  Episode 208 finished after 92 steps  and with total reward -9.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0018
#  Episode 209 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0026
#  Episode 210 finished after 48 steps  and with total reward -53.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7888
#  Episode 211 finished after 56 steps  and with total reward -45.0
# Epoch 1/1
# 64/64 [==============================] - 0s 63us/step - loss: 0.0023
#  Episode 212 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7875
#  Episode 213 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 30us/step - loss: 2.3566
#  Episode 214 finished after 84 steps  and with total reward -17.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 215 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0017
#  Episode 216 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7830
#  Episode 217 finished after 89 steps  and with total reward -12.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5746
#  Episode 218 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7847
#  Episode 219 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7828
#  Episode 220 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5766
#  Episode 221 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7830
#  Episode 222 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0022
#  Episode 223 finished after 92 steps  and with total reward -9.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0027
#  Episode 224 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5732
#  Episode 225 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0015
#  Episode 226 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7892
#  Episode 227 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3468
#  Episode 228 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5751
#  Episode 229 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0029
#  Episode 230 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7880
#  Episode 231 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7866
#  Episode 232 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0030
#  Episode 233 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0020
#  Episode 234 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0027
#  Episode 235 finished after 88 steps  and with total reward -13.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 236 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7820
#  Episode 237 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3543
#  Episode 238 finished after 81 steps  and with total reward -20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5831
#  Episode 239 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7833
#  Episode 240 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 3.1420
#  Episode 241 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3570
#  Episode 242 finished after 81 steps  and with total reward -20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7855
#  Episode 243 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7873
#  Episode 244 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7911
#  Episode 245 finished after 101 steps  and with total reward 0.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7913
#  Episode 246 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0025
#  Episode 247 finished after 90 steps  and with total reward -11.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7872
#  Episode 248 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0029
#  Episode 249 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5649
#  Episode 250 finished after 82 steps  and with total reward -19.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7885
#  Episode 251 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0030
#  Episode 252 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7885
#  Episode 253 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5807
#  Episode 254 finished after 51 steps  and with total reward -50.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5731
#  Episode 255 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0015
#  Episode 256 finished after 51 steps  and with total reward -50.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5662
#  Episode 257 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7848
#  Episode 258 finished after 81 steps  and with total reward -20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7844
#  Episode 259 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5637
#  Episode 260 finished after 81 steps  and with total reward -20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7907
#  Episode 261 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0028
#  Episode 262 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7842
#  Episode 263 finished after 82 steps  and with total reward -19.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5708
#  Episode 264 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0023
#  Episode 265 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0021
#  Episode 266 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5696
#  Episode 267 finished after 46 steps  and with total reward -55.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5763
#  Episode 268 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0017
#  Episode 269 finished after 78 steps  and with total reward -23.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 2.3615
#  Episode 270 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0024
#  Episode 271 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0026
#  Episode 272 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0018
#  Episode 273 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5701
#  Episode 274 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0031
#  Episode 275 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7849
#  Episode 276 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0028
#  Episode 277 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5740
#  Episode 278 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7921
#  Episode 279 finished after 84 steps  and with total reward -17.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5718
#  Episode 280 finished after 52 steps  and with total reward -49.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0031
#  Episode 281 finished after 99 steps  and with total reward -2.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7886
#  Episode 282 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7889
#  Episode 283 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5722
#  Episode 284 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7880
#  Episode 285 finished after 103 steps  and with total reward 2.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 286 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7875
#  Episode 287 finished after 52 steps  and with total reward -49.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5664
#  Episode 288 finished after 82 steps  and with total reward -19.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0031
#  Episode 289 finished after 48 steps  and with total reward -53.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5656
#  Episode 290 finished after 51 steps  and with total reward -50.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0030
#  Episode 291 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7860
#  Episode 292 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7883
#  Episode 293 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7843
#  Episode 294 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5720
#  Episode 295 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7895
#  Episode 296 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0022
#  Episode 297 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 298 finished after 46 steps  and with total reward -55.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0025
#  Episode 299 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0013
#  Episode 300 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0019
#  Episode 301 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7838
#  Episode 302 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7874
#  Episode 303 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0019
#  Episode 304 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5729
#  Episode 305 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7851
#  Episode 306 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.0020
#  Episode 307 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 1.5690
#  Episode 308 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7873
#  Episode 309 finished after 91 steps  and with total reward -10.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0020
#  Episode 310 finished after 91 steps  and with total reward -10.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 311 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0015
#  Episode 312 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 1.5729
#  Episode 313 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7835
#  Episode 314 finished after 90 steps  and with total reward -11.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5773
#  Episode 315 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5740
#  Episode 316 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 317 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7862
#  Episode 318 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0024
#  Episode 319 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0021
#  Episode 320 finished after 49 steps  and with total reward -52.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5736
#  Episode 321 finished after 72 steps  and with total reward -29.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7901
#  Episode 322 finished after 108 steps  and with total reward 7.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7899
#  Episode 323 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7889
#  Episode 324 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0024
#  Episode 325 finished after 56 steps  and with total reward -45.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7866
#  Episode 326 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0035
#  Episode 327 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7905
#  Episode 328 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7850
#  Episode 329 finished after 54 steps  and with total reward -47.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5692
#  Episode 330 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0027
# ...
#  Episode 390 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7888
#  Episode 391 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7853
#  Episode 392 finished after 92 steps  and with total reward -9.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 393 finished after 84 steps  and with total reward -17.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5660
#  Episode 394 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0015
#  Episode 395 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7830
#  Episode 396 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0018
#  Episode 397 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7879
#  Episode 398 finished after 84 steps  and with total reward -17.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0017
#  Episode 399 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7847
#  Episode 400 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7918
#  Episode 401 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5753
#  Episode 402 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 32us/step - loss: 1.5681
#  Episode 403 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7876
#  Episode 404 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7882
#  Episode 405 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0019
#  Episode 406 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0025
#  Episode 407 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5685
#  Episode 408 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0021
#  Episode 409 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7886
#  Episode 410 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 46us/step - loss: 1.5731
#  Episode 411 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0019
#  Episode 412 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7908
#  Episode 413 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5662
#  Episode 414 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0012
#  Episode 415 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7840
#  Episode 416 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0031
#  Episode 417 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7900
#  Episode 418 finished after 55 steps  and with total reward -46.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7866
#  Episode 419 finished after 92 steps  and with total reward -9.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 2.3604
#  Episode 420 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7827
#  Episode 421 finished after 63 steps  and with total reward -38.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 2.3567
#  Episode 422 finished after 54 steps  and with total reward -47.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5672
#  Episode 423 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5720
#  Episode 424 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0017
#  Episode 425 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0016
#  Episode 426 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5735
#  Episode 427 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7908
#  Episode 428 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7850
#  Episode 429 finished after 97 steps  and with total reward -4.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5747
#  Episode 430 finished after 59 steps  and with total reward -42.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5700
#  Episode 431 finished after 67 steps  and with total reward -34.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5722
#  Episode 432 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5706
#  Episode 433 finished after 103 steps  and with total reward 2.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5686
#  Episode 434 finished after 112 steps  and with total reward 11.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7865
#  Episode 435 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5791
#  Episode 436 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 32us/step - loss: 0.0016
#  Episode 437 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7873
#  Episode 438 finished after 86 steps  and with total reward -15.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.7833
#  Episode 439 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 440 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7873
#  Episode 441 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 2.3572
#  Episode 442 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7927
#  Episode 443 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5710
#  Episode 444 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7840
#  Episode 445 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7872
#  Episode 446 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0021
#  Episode 447 finished after 56 steps  and with total reward -45.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7843
#  Episode 448 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7826
#  Episode 449 finished after 48 steps  and with total reward -53.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7864
#  Episode 450 finished after 95 steps  and with total reward -6.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7812
#  Episode 451 finished after 81 steps  and with total reward -20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7855
#  Episode 452 finished after 75 steps  and with total reward -26.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0021
#  Episode 453 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0014
#  Episode 454 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 2.3560
#  Episode 455 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5706
#  Episode 456 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7887
#  Episode 457 finished after 121 steps  and with total reward 20.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7861
#  Episode 458 finished after 77 steps  and with total reward -24.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7877
#  Episode 459 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0022
#  Episode 460 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 1.5711
#  Episode 461 finished after 45 steps  and with total reward -56.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 1.5695
#  Episode 462 finished after 61 steps  and with total reward -40.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7884
#  Episode 463 finished after 93 steps  and with total reward -8.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7870
#  Episode 464 finished after 86 steps  and with total reward -15.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5686
#  Episode 465 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0020
#  Episode 466 finished after 87 steps  and with total reward -14.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7860
#  Episode 467 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0020
#  Episode 468 finished after 95 steps  and with total reward -6.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7871
#  Episode 469 finished after 71 steps  and with total reward -30.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5766
#  Episode 470 finished after 85 steps  and with total reward -16.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0020
#  Episode 471 finished after 94 steps  and with total reward -7.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 2.3560
#  Episode 472 finished after 76 steps  and with total reward -25.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0017
#  Episode 473 finished after 86 steps  and with total reward -15.0
# Epoch 1/1
# 64/64 [==============================] - 0s 15us/step - loss: 0.7894
#  Episode 474 finished after 74 steps  and with total reward -27.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7861
#  Episode 475 finished after 43 steps  and with total reward -58.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7834
#  Episode 476 finished after 57 steps  and with total reward -44.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0014
#  Episode 477 finished after 65 steps  and with total reward -36.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7806
#  Episode 478 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7832
#  Episode 479 finished after 70 steps  and with total reward -31.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0016
#  Episode 480 finished after 51 steps  and with total reward -50.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0021
#  Episode 481 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0030
#  Episode 482 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0023
#  Episode 483 finished after 66 steps  and with total reward -35.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7907
#  Episode 484 finished after 58 steps  and with total reward -43.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 0.0036
#  Episode 485 finished after 45 steps  and with total reward -56.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0014
#  Episode 486 finished after 60 steps  and with total reward -41.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0018
#  Episode 487 finished after 79 steps  and with total reward -22.0
# Epoch 1/1
# 64/64 [==============================] - 0s 47us/step - loss: 2.3558
#  Episode 488 finished after 73 steps  and with total reward -28.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0024
#  Episode 489 finished after 50 steps  and with total reward -51.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0024
#  Episode 490 finished after 80 steps  and with total reward -21.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.0025
#  Episode 491 finished after 50 steps  and with total reward -51.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.0014
#  Episode 492 finished after 45 steps  and with total reward -56.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7880
#  Episode 493 finished after 62 steps  and with total reward -39.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 0.7821
#  Episode 494 finished after 64 steps  and with total reward -37.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7924
#  Episode 495 finished after 89 steps  and with total reward -12.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5664
#  Episode 496 finished after 68 steps  and with total reward -33.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5772
#  Episode 497 finished after 93 steps  and with total reward -8.0
# Epoch 1/1
# 64/64 [==============================] - 0s 31us/step - loss: 1.5704
#  Episode 498 finished after 69 steps  and with total reward -32.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 0.7827
#  Episode 499 finished after 83 steps  and with total reward -18.0
# Epoch 1/1
# 64/64 [==============================] - 0s 16us/step - loss: 1.5624

# %%
agent.test(10)
print('Complete')

# %%
agent.network.get_model().save_weights("cart.h5")

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import time

def pltsin(ax, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    fig.canvas.draw()

fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
for f in range(5):
    pltsin(ax, ['b', 'r'])
    time.sleep(1)
# Out:
# <img src="data:image/png;base64,..." width="640">
