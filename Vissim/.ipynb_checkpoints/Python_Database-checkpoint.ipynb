# %% [markdown]
# # Results
#
# This notebook is to save the result of our simulation

# %%
# %load_ext sql
import pandas as pd
import sqlite3
import pylab as plt
import os
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
model_name  = 'Single_Cross_Straight'
# 'Single_Cross_Straight'
# 'Single_Cross_Triple'
# 'Single_Cross_Triple_Mod'
# 'Single_Cross_Mod2'
# 'Balance'

agent_type = 'AC'        # DQN, DuelingDQN, DDQN, DuelingDDQN AC SURTRAC MOVA

# different demand shape
demand = 'demand1'

# hyperparameter and NN shape of the leaning
lr = 'lr_0.000065'
entropy = 'e_0.00001'
structure = 'C_0/V_1*42/P_1*42'
n_step = 'n_step_32'
gamma = 'gamma_0.99'




# Path to the database
DBPATH = os.path.join(model_name,model_name +'.results','1.db')

# %%
# Connect to the database
conn = sqlite3.connect(DBPATH)

# %%
# Select the appropriate metric the cumulative delay and the cumulative stop delay

df = pd.read_sql_query('SELECT \
                    CAST(ARG_TIMEINTERVAL AS BIGINT) AS Time, \
                    sum(STOPDELAY) OVER (ORDER BY CAST(ARG_TIMEINTERVAL AS BIGINT)) as CumStopDelay, \
                    sum(VEHDELAY) OVER (ORDER BY CAST(ARG_TIMEINTERVAL AS BIGINT)) as CumDelay \
                    FROM DELAYMEASUREMENT_EvaluationTimeIntervalClass' ,conn)

# %%
df
# Out:
#        Time  CumStopDelay      CumDelay
# 0         1           NaN           NaN
# 1         1           NaN           NaN
# 2         1           NaN           NaN
# 3         1           NaN           NaN
# 4         2           NaN           NaN
# 5         2           NaN           NaN
# 6         2           NaN           NaN
# 7         2           NaN           NaN
# 8         3           NaN           NaN
# 9         3           NaN           NaN
# 10        3           NaN           NaN
# 11        3           NaN           NaN
# 12        4           NaN           NaN
# 13        4           NaN           NaN
# 14        4           NaN           NaN
# 15        4           NaN           NaN
# 16        5           NaN           NaN
# 17        5           NaN           NaN
# 18        5           NaN           NaN
# 19        5           NaN           NaN
# 20        6           NaN           NaN
# 21        6           NaN           NaN
# 22        6           NaN           NaN
# 23        6           NaN           NaN
# 24        7           NaN           NaN
# 25        7           NaN           NaN
# 26        7           NaN           NaN
# 27        7           NaN           NaN
# 28        8           NaN           NaN
# 29        8           NaN           NaN
# ...     ...           ...           ...
# 14370  3593   1140.775872  10241.376787
# 14371  3593   1140.775872  10241.376787
# 14372  3594   1140.775872  10241.376787
# 14373  3594   1140.775872  10241.376787
# 14374  3594   1140.775872  10241.376787
# 14375  3594   1140.775872  10241.376787
# 14376  3595   1140.775872  10241.376787
# 14377  3595   1140.775872  10241.376787
# 14378  3595   1140.775872  10241.376787
# 14379  3595   1140.775872  10241.376787
# 14380  3596   1140.775872  10241.376787
# 14381  3596   1140.775872  10241.376787
# 14382  3596   1140.775872  10241.376787
# 14383  3596   1140.775872  10241.376787
# 14384  3597   1140.775872  10241.376787
# 14385  3597   1140.775872  10241.376787
# 14386  3597   1140.775872  10241.376787
# 14387  3597   1140.775872  10241.376787
# 14388  3598   1140.775872  10241.813127
# 14389  3598   1140.775872  10241.813127
# 14390  3598   1140.775872  10241.813127
# 14391  3598   1140.775872  10241.813127
# 14392  3599   1140.775872  10241.813127
# 14393  3599   1140.775872  10241.813127
# 14394  3599   1140.775872  10241.813127
# 14395  3599   1140.775872  10241.813127
# 14396  3600   1140.775872  10241.813127
# 14397  3600   1140.775872  10241.813127
# 14398  3600   1140.775872  10241.813127
# 14399  3600   1140.775872  10241.813127
#
# [14400 rows x 3 columns]

# %%
# plot the result of the current model

plt.plot(range(df['Time'][14399]),df['CumStopDelay'][::4], label = 'Cumulative_Stopdelay' )
plt.plot(range(df['Time'][14399]),df['CumDelay'][::4], label = 'Cumulative_Delay')

plt.legend()

# %%
results_path = 'results_'+ model_name +'_' +demand + '.csv'

# %%
# Open the files containing the result of all the simulation
results_path = 'results_'+ model_name +'_'+demand + '.csv'

results = pd.read_csv(results_path)

# %%
# Add the current result to our result table

results[agent_type+lr+entropy+structure+n_step+gamma+'CumStopDelay'] = df['CumStopDelay']
results[agent_type+lr+entropy+structure+n_step+gamma+'CumDelay'] = df['CumDelay']

# %%
# Saving the result in a files !!!! Be careful not to erase everything....  !!!!


results.to_csv(results_path)

# %%
bla = pd.DataFrame()

# %%
bla.to_csv(results_path)

# %%
bla['Time']
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           2
# 5           2
# 6           2
# 7           2
# 8           3
# 9           3
# 10          3
# 11          3
# 12          4
# 13          4
# 14          4
# 15          4
# 16          5
# 17          5
# 18          5
# 19          5
# 20          6
# 21          6
# 22          6
# 23          6
# 24          7
# 25          7
# 26          7
# 27          7
# 28          8
# 29          8
#          ...
# 14374    3594
# 14375    3594
# 14376    3595
# 14377    3595
# 14378    3595
# 14379    3595
# 14380    3596
# 14381    3596
# 14382    3596
# 14383    3596
# 14384    3597
# 14385    3597
# 14386    3597
# 14387    3597
# 14388    3598
# 14389    3598
# 14390    3598
# 14391    3598
# 14392    3599
# 14393    3599
# 14394    3599
# 14395    3599
# 14396    3600
# 14397    3600
# 14398    3600
# 14399    3600
# 14400    3601
# 14401    3601
# 14402    3601
# 14403    3601
# Name: Time, Length: 14404, dtype: int64
