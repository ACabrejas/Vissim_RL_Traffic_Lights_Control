# %%
## VISSIM Modules
import win32com.client as com
import os

## RL Modules
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("ERROR: GPU DEVICE NOT FOUND.")

from tensorflow.keras.models import load_model
    
## Data Management Modules
import pickle

## User Defined Modules
import math
import Simulator_Functions as SF

from Actor_Critic_Agents import ACAgent



from NParser import NetworkParser
from COMServer import COMServerDispatch, COMServerReload
from TupleToList import toList
from Utilities import log_progress, pltlive
## Other Modules
import numpy as np
import random
import matplotlib.pyplot as plt
import PER

# %matplotlib inline
# Out:
# ERROR: GPU DEVICE NOT FOUND.

# %%
## RL Hyperparamenters
# Number of simulations, save every "n" episodes 
episodes =200
partial_save_at = 50



# Hyperparameters
Surtrac = False
AC = True
PER_activated = False


alpha   = 0.000065
gamma   = 0.99
n_step_size = 32 # number of sstep in the n step learning

# Timesteps per simulation (1 timestep = 0.1 sec), length for random population is a multiple of episode
timesteps_per_second = 1
seconds_per_green = 6
seconds_per_yellow = 3
simulation_length = 3600*1 + 1 # worked with 2400



## State-Action Parameters
action_type = "phases"        # options are "phases" and "programs"
state_size = 6 # 4 queues or 6 queues + signal state
action_size = 2

# Demand Schedule (times in seconds, demand in cars/hour as PPP) # worked with 600
demand_change_timesteps = 450
demand = {"h":600, 'm':300, 'l':150}
demand_list = [[demand['l'], demand['l']], [demand['m'], demand['l']],\
              [demand['h'], demand['l']], [demand['h'], demand['m']],\
              [demand['h'], demand['h']], [demand['m'], demand['h']],
              [demand['l'], demand['h']], [demand['l'], demand['m']]]

# %%
## Operation mode (selects functionalities)
mode = "training"

# "training" = training agents, maximum speed, frozen UI, mid amount of messages
# "debug"    = trains for 1 episode, minimum speed, working UI, all messages
# "demo"     = loads pretrained agent, minimum speed, working UI
# "test"     = executes evaluation, maximum speed


if mode == 'demo' :
    simulation_length = 3600
    demand_list = [[demand['l'], demand['l']]]
    demand_change_timesteps = simulation_length

if mode == 'test' : 
    simulation_length = 3600
    demand_change_timesteps = 450
    demand = {"h":800, 'm':400, 'l':200}
    demand_list = [[demand['l'], demand['l']], [demand['m'], demand['l']],\
                  [demand['h'], demand['l']], [demand['h'], demand['m']],\
                  [demand['h'], demand['h']], [demand['m'], demand['h']],
                  [demand['l'], demand['h']], [demand['l'], demand['m']]]

## Network Model Parameters
model_name  = 'Single_Cross_Straight'
# 'Single_Cross_Straight'
# 'Single_Cross_Triple'
# 'Balance'

vissim_working_directory =  'C:\\Users\\Rzhang\\Desktop\\MLforFlowOptimisationOrigine\\Vissim\\'
agent_type = 'ActorCritic' # DQN, DuelingDQN, DDQN, DuelingDDQN ActorCritic
reward_type = 'Queues'
state_type  = 'QueuesSig'    # 'Queues', 'Delays', 'QueuesDifference' 'QueuesSpeedavrOccuperateSig' 'QueuesSig'
Random_Seed = 42

## Use of additional files?
flag_read_additionally  = True
SaveResultsAgent = True
# Random demand
Random_Demand = False

# Session ID
#Session_ID = 'Ep_'+str(episodes)+'_A_'+agent_type+"_Act_"+action_type+"_Rew_"+reward_type

# Adding the state type to the Session_ID
Session_ID = 'Ep_'+str(episodes)+'_A_'+agent_type+"_State_"+state_type+"_Act_"+action_type+"_Rew_"+reward_type
print(Session_ID)
# Out:
# Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues

# %%
# Have to find a way to reduce entropy over time entropy = exploration

## Converging network
# - reward queue, state queue
# converging with updates every steps and entropy = 0.00001 and 1 core layer of 42
# converging well with updates every steps and entropy = 0.00001 and 1 core layer of 128

# - reward queue state queues + sig
# converging well with updates every steps and entropy = 0.00001 and 1 core layer of 128

if __name__ == "__main__":
    # Initialize storage
    reward_storage = []
    best_agent_weights = []
    best_agent_memory = []
    reward_plot = np.zeros([episodes,])
    loss_plot = np.zeros([episodes,])

    # Initialize simulation
    Vissim, Simulation, Network, cache_flag = COMServerDispatch(model_name, vissim_working_directory,\
                                                                simulation_length, timesteps_per_second,\
                                                                delete_results = True, verbose = True)
    SF.Select_Vissim_Mode(Vissim,mode)
    
    runflag = True
    # Setting Random Seed
    Vissim.Simulation.SetAttValue('RandSeed', Random_Seed)
    print ('Random seed set in simulator. Random Seed = '+str(Random_Seed))

    # Deploy Network Parser (crawl network)
    npa = NetworkParser(Vissim)
    print('NetworkParser has succesfully crawled the model network.')
    
    # Initialize agents
    if agent_type in ['ActorCritic'] :
        Agents = [ACAgent(state_size, action_size, ID, state_type, npa, n_step_size, gamma, alpha, Vissim) for ID in npa.signal_controllers_ids] 
        for agent in Agents:
            # to initialise the computational graph ot the model (I am sure there is a better way to to this)
            agent.test()
        agents_deployed = True
    else:
        print("Incorrect Agent Class selected. Deployment could not be completed.")
        quit()
    if agents_deployed:
        print("Deployed {} agent(s) of the Class {}.".format(len(Agents), agent_type))
    
    ## EXECUTION OF A DEMONSTRATION RUN (slow, choice of best available agent)
    if mode == "demo" or mode == "populate" or mode == "debug" or mode == "test":
        # If mode or debug, set slow simulation
        if mode == "demo" or mode =="debug":
            timesteps_per_second = 10
            Vissim.Simulation.SetAttValue('SimRes', timesteps_per_second)
            
        # If memory population or test mode, set quick simulation
        elif mode == "populate" or mode == "test":
            SF.Set_Quickmode(Vissim, timesteps_per_second)
            
        # If on a test or a demo, load the best available agent and set exploration to zero
        if mode == "demo" or mode == "test":
            Agents , reward_storage = SF.load_agents(vissim_working_directory, model_name, Agents,\
                                    Session_ID, best = True)
            for agent in Agents:
                agent.epsilon = 0
                
    # Run the episode
        if mode == "demo" or mode == "debug":
            SF.run_simulation_episode(Agents, Vissim, state_type, reward_type, state_size, memory_population_length,\
                                      timesteps_per_second, seconds_per_green, seconds_per_yellow,\
                                      demand_list, demand_change_timesteps, mode, PER_activated)
        elif mode == "test":
            SF.run_simulation_episode(Agents, Vissim, state_type, reward_type, state_size, simulation_length,\
                                      timesteps_per_second, seconds_per_green, seconds_per_yellow,\
                                      demand_list, demand_change_timesteps, mode, PER_activated)
        elif mode == "populate":
            if PER_activated:
                memory, Agents, runflag = SF.prepopulate_memory(Agents, Vissim, state_type, reward_type, state_size, memory_size,\
                                                                vissim_working_directory, model_name, Session_ID,\
                                                                seconds_per_green, seconds_per_green, timesteps_per_second,\
                                                                demand_list, demand_change_timesteps, PER_activated)
                print("PER memory prepopulated with {} entries".format(memory_size))
        
        Vissim = None
    
    ## EXECUTION OF THE NORMAL TRAINING LOOP
    elif mode == "training":
        print("Training")
        
            
        # Iterations of the simulation
        for episode in log_progress(range(episodes), every=1):
        
            # Reload map if it has already been run (previous episode or prepopulation)
            if episode !=0 or runflag == True:
                Simulation, Network = COMServerReload(Vissim, model_name, vissim_working_directory,\
                                                      simulation_length, timesteps_per_second, delete_results = True)

                # Run Network Parser and ensure agents are linked to their intersections
                #npa.update(Vissim) 
                npa = NetworkParser(Vissim)
                for index, agent in enumerate(Agents):
                    #agent.update_IDS(npa.signal_controllers_ids[index], npa)
                    agent.update_IDS(agent.signal_id, npa)
                    agent.episode_reward = []

            # Change the random seed
            Random_Seed += 1
            Vissim.Simulation.SetAttValue('RandSeed', Random_Seed)
        
            # Run Episode at maximum speed
            SF.Set_Quickmode(Vissim, timesteps_per_second)
            SF.Select_Vissim_Mode(Vissim,mode)
            
            SF.run_simulation_episode(Agents, Vissim, state_type, reward_type, state_size, simulation_length, timesteps_per_second,\
                                      seconds_per_green, seconds_per_yellow, demand_list, demand_change_timesteps, mode,\
                                      PER_activated,Surtrac = Surtrac, AC = AC)
        
            # Calculate episode average reward
            reward_storage, average_reward = SF.average_reward(reward_storage, Agents, episode, episodes)
            best_agent_weights, best_agent_memory = SF.best_agent(reward_storage, average_reward,\
                                                                  best_agent_weights, best_agent_memory,\
                                                                  vissim_working_directory, model_name, Agents, Session_ID)
        
            
            # Security save for long trainings
            if SaveResultsAgent:
                if (episode+1)%partial_save_at == 0:
                    SF.save_agents(vissim_working_directory, model_name, Agents, Session_ID, reward_storage)
                    print('Saved Partial results at the end of episode {}.'.format(episode+1))

        #Saving agents memory, weights and optimizer
        if SaveResultsAgent:
            SF.save_agents(vissim_working_directory, model_name, Agents, Session_ID, reward_storage)
            print("Model, architecture, weights, optimizer, memory and training results succesfully saved.\
            Succesfully Terminated.")
    
    else:
        print("ERROR: Mode selected not recognized. TERMINATING.")
    # Close Vissim
    Vissim = None
# Out:
# Working Directory set to: C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\
# Generating Cache...
# Cache generated.
#
# ****************************
# *   COM Server dispatched  *
# ****************************
#
# Attempting to load Model File: Single_Cross_Straight.inpx ...
# Load process successful
# Simulation length set to 3601 seconds.
# Results from Previous Simulations: Deleted. Fresh Start Available.
# Fetched and containerized Simulation Object
# Fetched and containerized Network Object
#
# *******************************************************
# *                                                     *
# *                 SETUP COMPLETE                      *
# *                                                     *
# *******************************************************
#
# Random seed set in simulator. Random Seed = 42
# NetworkParser has succesfully crawled the model network.
# Deploying instance of Actor_Critic Agent(s) !!! TENSORFLOW 2 IS NEEDED !!!
# Deployed 1 agent(s) of the Class ActorCritic.
# Training
# VBox(children=(HTML(value=''), IntProgress(value=0, max=200)))
# Episode: 1/200, Epsilon:0, Average reward: -374.04
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 2/200, Epsilon:0, Average reward: -371.62
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 3/200, Epsilon:0, Average reward: -288.95
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 4/200, Epsilon:0, Average reward: -202.38
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 5/200, Epsilon:0, Average reward: -43.08
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 6/200, Epsilon:0, Average reward: -12.48
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 7/200, Epsilon:0, Average reward: -23.79
# Episode: 8/200, Epsilon:0, Average reward: -254.05
# Episode: 9/200, Epsilon:0, Average reward: -16.07
# Episode: 10/200, Epsilon:0, Average reward: -83.18
# Episode: 11/200, Epsilon:0, Average reward: -177.55
# Episode: 12/200, Epsilon:0, Average reward: -87.55
# Episode: 13/200, Epsilon:0, Average reward: -14.48
# Episode: 14/200, Epsilon:0, Average reward: -10.78
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 15/200, Epsilon:0, Average reward: -10.58
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 16/200, Epsilon:0, Average reward: -14.23
# Episode: 17/200, Epsilon:0, Average reward: -11.97
# Episode: 18/200, Epsilon:0, Average reward: -10.72
# Episode: 19/200, Epsilon:0, Average reward: -12.18
# Episode: 20/200, Epsilon:0, Average reward: -12.16
# Episode: 21/200, Epsilon:0, Average reward: -11.42
# Episode: 22/200, Epsilon:0, Average reward: -11.17
# Episode: 23/200, Epsilon:0, Average reward: -10.21
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 24/200, Epsilon:0, Average reward: -11.11
# Episode: 25/200, Epsilon:0, Average reward: -10.12
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 26/200, Epsilon:0, Average reward: -10.43
# Episode: 27/200, Epsilon:0, Average reward: -10.21
# Episode: 28/200, Epsilon:0, Average reward: -44.86
# Episode: 29/200, Epsilon:0, Average reward: -10.92
# Episode: 30/200, Epsilon:0, Average reward: -10.83
# Episode: 31/200, Epsilon:0, Average reward: -12.55
# Episode: 32/200, Epsilon:0, Average reward: -11.35
# Episode: 33/200, Epsilon:0, Average reward: -13.34
# Episode: 34/200, Epsilon:0, Average reward: -10.87
# Episode: 35/200, Epsilon:0, Average reward: -10.78
# Episode: 36/200, Epsilon:0, Average reward: -10.07
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 37/200, Epsilon:0, Average reward: -12.27
# Episode: 38/200, Epsilon:0, Average reward: -11.53
# Episode: 39/200, Epsilon:0, Average reward: -12.57
# Episode: 40/200, Epsilon:0, Average reward: -12.44
# Episode: 41/200, Epsilon:0, Average reward: -14.42
# Episode: 42/200, Epsilon:0, Average reward: -10.8
# Episode: 43/200, Epsilon:0, Average reward: -11.47
# Episode: 44/200, Epsilon:0, Average reward: -10.73
# Episode: 45/200, Epsilon:0, Average reward: -11.5
# Episode: 46/200, Epsilon:0, Average reward: -12.47
# Episode: 47/200, Epsilon:0, Average reward: -10.1
# Episode: 48/200, Epsilon:0, Average reward: -11.56
# Episode: 49/200, Epsilon:0, Average reward: -12.12
# Episode: 50/200, Epsilon:0, Average reward: -13.25
# Saving architecture, weights state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Saved Partial results at the end of episode 50.
# Episode: 51/200, Epsilon:0, Average reward: -14.17
# Episode: 52/200, Epsilon:0, Average reward: -12.17
# Episode: 53/200, Epsilon:0, Average reward: -11.47
# Episode: 54/200, Epsilon:0, Average reward: -10.72
# Episode: 55/200, Epsilon:0, Average reward: -10.54
# Episode: 56/200, Epsilon:0, Average reward: -11.87
# Episode: 57/200, Epsilon:0, Average reward: -9.9
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 58/200, Epsilon:0, Average reward: -10.37
# Episode: 59/200, Epsilon:0, Average reward: -10.11
# Episode: 60/200, Epsilon:0, Average reward: -10.9
# Episode: 61/200, Epsilon:0, Average reward: -12.04
# Episode: 62/200, Epsilon:0, Average reward: -10.36
# Episode: 63/200, Epsilon:0, Average reward: -9.41
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 64/200, Epsilon:0, Average reward: -10.22
# Episode: 65/200, Epsilon:0, Average reward: -10.62
# Episode: 66/200, Epsilon:0, Average reward: -10.24
# Episode: 67/200, Epsilon:0, Average reward: -10.0
# Episode: 68/200, Epsilon:0, Average reward: -9.99
# Episode: 69/200, Epsilon:0, Average reward: -10.03
# Episode: 70/200, Epsilon:0, Average reward: -11.77
# Episode: 71/200, Epsilon:0, Average reward: -9.08
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 72/200, Epsilon:0, Average reward: -10.08
# Episode: 73/200, Epsilon:0, Average reward: -10.62
# Episode: 74/200, Epsilon:0, Average reward: -10.0
# Episode: 75/200, Epsilon:0, Average reward: -13.09
# Episode: 76/200, Epsilon:0, Average reward: -14.76
# Episode: 77/200, Epsilon:0, Average reward: -12.43
# Episode: 78/200, Epsilon:0, Average reward: -11.9
# Episode: 79/200, Epsilon:0, Average reward: -10.12
# Episode: 80/200, Epsilon:0, Average reward: -10.73
# Episode: 81/200, Epsilon:0, Average reward: -12.62
# Episode: 82/200, Epsilon:0, Average reward: -9.95
# Episode: 83/200, Epsilon:0, Average reward: -11.4
# Episode: 84/200, Epsilon:0, Average reward: -11.91
# Episode: 85/200, Epsilon:0, Average reward: -13.29
# Episode: 86/200, Epsilon:0, Average reward: -10.15
# Episode: 87/200, Epsilon:0, Average reward: -10.72
# Episode: 88/200, Epsilon:0, Average reward: -11.09
# Episode: 89/200, Epsilon:0, Average reward: -11.6
# Episode: 90/200, Epsilon:0, Average reward: -11.02
# Episode: 91/200, Epsilon:0, Average reward: -10.62
# Episode: 92/200, Epsilon:0, Average reward: -10.44
# Episode: 93/200, Epsilon:0, Average reward: -8.63
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 94/200, Epsilon:0, Average reward: -10.02
# Episode: 95/200, Epsilon:0, Average reward: -10.21
# Episode: 96/200, Epsilon:0, Average reward: -11.74
# Episode: 97/200, Epsilon:0, Average reward: -10.59
# Episode: 98/200, Epsilon:0, Average reward: -10.3
# Episode: 99/200, Epsilon:0, Average reward: -11.69
# Episode: 100/200, Epsilon:0, Average reward: -11.08
# Saving architecture, weights state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Saved Partial results at the end of episode 100.
# Episode: 101/200, Epsilon:0, Average reward: -12.26
# Episode: 102/200, Epsilon:0, Average reward: -12.41
# Episode: 103/200, Epsilon:0, Average reward: -11.27
# Episode: 104/200, Epsilon:0, Average reward: -10.29
# Episode: 105/200, Epsilon:0, Average reward: -10.88
# Episode: 106/200, Epsilon:0, Average reward: -11.25
# Episode: 107/200, Epsilon:0, Average reward: -13.65
# Episode: 108/200, Epsilon:0, Average reward: -15.66
# Episode: 109/200, Epsilon:0, Average reward: -13.47
# Episode: 110/200, Epsilon:0, Average reward: -216.85
# Episode: 111/200, Epsilon:0, Average reward: -276.28
# Episode: 112/200, Epsilon:0, Average reward: -272.27
# Episode: 113/200, Epsilon:0, Average reward: -75.56
# Episode: 114/200, Epsilon:0, Average reward: -13.47
# Episode: 115/200, Epsilon:0, Average reward: -200.1
# Episode: 116/200, Epsilon:0, Average reward: -22.6
# Episode: 117/200, Epsilon:0, Average reward: -14.28
# Episode: 118/200, Epsilon:0, Average reward: -11.12
# Episode: 119/200, Epsilon:0, Average reward: -12.17
# Episode: 120/200, Epsilon:0, Average reward: -12.49
# Episode: 121/200, Epsilon:0, Average reward: -9.35
# Episode: 122/200, Epsilon:0, Average reward: -10.68
# Episode: 123/200, Epsilon:0, Average reward: -12.64
# Episode: 124/200, Epsilon:0, Average reward: -11.56
# Episode: 125/200, Epsilon:0, Average reward: -10.58
# Episode: 126/200, Epsilon:0, Average reward: -10.32
# Episode: 127/200, Epsilon:0, Average reward: -9.36
# Episode: 128/200, Epsilon:0, Average reward: -10.67
# Episode: 129/200, Epsilon:0, Average reward: -8.89
# Episode: 130/200, Epsilon:0, Average reward: -10.14
# Episode: 131/200, Epsilon:0, Average reward: -12.39
# Episode: 132/200, Epsilon:0, Average reward: -9.54
# Episode: 133/200, Epsilon:0, Average reward: -10.83
# Episode: 134/200, Epsilon:0, Average reward: -9.68
# Episode: 135/200, Epsilon:0, Average reward: -11.59
# Episode: 136/200, Epsilon:0, Average reward: -11.09
# Episode: 137/200, Epsilon:0, Average reward: -9.27
# Episode: 138/200, Epsilon:0, Average reward: -9.98
# Episode: 139/200, Epsilon:0, Average reward: -10.63
# Episode: 140/200, Epsilon:0, Average reward: -10.42
# Episode: 141/200, Epsilon:0, Average reward: -9.46
# Episode: 142/200, Epsilon:0, Average reward: -9.41
# Episode: 143/200, Epsilon:0, Average reward: -10.94
# Episode: 144/200, Epsilon:0, Average reward: -12.13
# Episode: 145/200, Epsilon:0, Average reward: -8.35
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 146/200, Epsilon:0, Average reward: -12.17
# Episode: 147/200, Epsilon:0, Average reward: -10.87
# Episode: 148/200, Epsilon:0, Average reward: -10.09
# Episode: 149/200, Epsilon:0, Average reward: -10.27
# Episode: 150/200, Epsilon:0, Average reward: -9.74
# Saving architecture, weights state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Saved Partial results at the end of episode 150.
# Episode: 151/200, Epsilon:0, Average reward: -11.85
# Episode: 152/200, Epsilon:0, Average reward: -9.66
# Episode: 153/200, Epsilon:0, Average reward: -10.11
# Episode: 154/200, Epsilon:0, Average reward: -11.29
# Episode: 155/200, Epsilon:0, Average reward: -9.63
# Episode: 156/200, Epsilon:0, Average reward: -10.99
# Episode: 157/200, Epsilon:0, Average reward: -9.27
# Episode: 158/200, Epsilon:0, Average reward: -10.86
# Episode: 159/200, Epsilon:0, Average reward: -8.45
# Episode: 160/200, Epsilon:0, Average reward: -11.3
# Episode: 161/200, Epsilon:0, Average reward: -10.62
# Episode: 162/200, Epsilon:0, Average reward: -8.91
# Episode: 163/200, Epsilon:0, Average reward: -8.33
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 164/200, Epsilon:0, Average reward: -11.08
# Episode: 165/200, Epsilon:0, Average reward: -10.32
# Episode: 166/200, Epsilon:0, Average reward: -10.13
# Episode: 167/200, Epsilon:0, Average reward: -10.32
# Episode: 168/200, Epsilon:0, Average reward: -10.2
# Episode: 169/200, Epsilon:0, Average reward: -11.44
# Episode: 170/200, Epsilon:0, Average reward: -9.96
# Episode: 171/200, Epsilon:0, Average reward: -11.92
# Episode: 172/200, Epsilon:0, Average reward: -13.76
# Episode: 173/200, Epsilon:0, Average reward: -11.17
# Episode: 174/200, Epsilon:0, Average reward: -12.13
# Episode: 175/200, Epsilon:0, Average reward: -10.74
# Episode: 176/200, Epsilon:0, Average reward: -11.81
# Episode: 177/200, Epsilon:0, Average reward: -9.09
# Episode: 178/200, Epsilon:0, Average reward: -8.41
# Episode: 179/200, Epsilon:0, Average reward: -11.77
# Episode: 180/200, Epsilon:0, Average reward: -10.83
# Episode: 181/200, Epsilon:0, Average reward: -10.44
# Episode: 182/200, Epsilon:0, Average reward: -11.28
# Episode: 183/200, Epsilon:0, Average reward: -11.43
# Episode: 184/200, Epsilon:0, Average reward: -12.69
# Episode: 185/200, Epsilon:0, Average reward: -11.27
# Episode: 186/200, Epsilon:0, Average reward: -10.46
# Episode: 187/200, Epsilon:0, Average reward: -11.3
# Episode: 188/200, Epsilon:0, Average reward: -10.52
# Episode: 189/200, Epsilon:0, Average reward: -10.46
# Episode: 190/200, Epsilon:0, Average reward: -9.38
# Episode: 191/200, Epsilon:0, Average reward: -7.67
# New best agent found. Saved in C:\Users\Rzhang\Desktop\MLforFlowOptimisationOrigine\Vissim\Single_Cross_Straight\Agents_Results\Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues\Single_Cross_Straight_Ep_200_A_ActorCritic_State_QueuesSig_Act_phases_Rew_Queues_BestAgent0_Memory.p
# Episode: 192/200, Epsilon:0, Average reward: -8.85
# Episode: 193/200, Epsilon:0, Average reward: -8.86
# Episode: 194/200, Epsilon:0, Average reward: -9.55
# Episode: 195/200, Epsilon:0, Average reward: -8.75
# Episode: 196/200, Epsilon:0, Average reward: -10.48
# Episode: 197/200, Epsilon:0, Average reward: -9.79
# Episode: 198/200, Epsilon:0, Average reward: -9.21
# Episode: 199/200, Epsilon:0, Average reward: -10.71
# Episode: 200/200, Epsilon:0, Average reward: -10.65
# Saving architecture, weights state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Saved Partial results at the end of episode 200.
# Saving architecture, weights state for agent-0
# Dumping agent-0 memory into pickle file
# Dumping Training Results into pickle file.
# Dumping Loss Results into pickle file.
# Model, architecture, weights, optimizer, memory and training results succesfully saved.            Succesfully Terminated.

# %%
# Plotting training progress
plt.figure(figsize=(8,4.5))
x_series = range(1,len(reward_storage)+1)
fit = np.polyfit(x_series,reward_storage,1)
fit_fn = np.poly1d(fit) 
plt.plot(x_series,reward_storage, '-b', x_series, fit_fn(x_series), '--r')
plt.xlabel('Episodes')
plt.ylabel('Average agent reward in episode')
plt.title('Training evolution and trend')
plt.gca().legend(('Episode Reward','Linear Trend'))
plt.show()

# Plotting training loss
plt.figure(figsize=(8,4.5))
x_series = range(1,len(Agents[0].loss)+1)
plt.plot(x_series,Agents[0].loss, '-b')
plt.xlabel('Training Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.gca().legend(('Loss'))
plt.show()

print(reward_storage)
# Out:
# [-374.04317334141655, -371.6230874679013, -288.95246905975705, -202.38303561369594, -43.079092877540724, -12.482195930895418, -23.786097041018728, -254.0464703101591, -16.068282832031286, -83.17948449293495, -177.54853449531214, -87.54531686884361, -14.477519765339013, -10.777965565322008, -10.575288901797041, -14.227529040185763, -11.974454524630401, -10.724644557792303, -12.183356890946888, -12.16417012703816, -11.421276894127278, -11.172327281214532, -10.209675765783771, -11.107288262353231, -10.116627496577054, -10.434265895931128, -10.207968941742378, -44.86368740076001, -10.920255922863145, -10.830553414182098, -12.549407176047614, -11.351939518428381, -13.34223403647215, -10.87331357550954, -10.779857095212911, -10.074841917619423, -12.274534890351886, -11.532457879454908, -12.566733840228924, -12.444796259414243, -14.420202324393676, -10.804160247446903, -11.472191719377848, -10.725832779613917, -11.50281085226935, -12.474774281463196, -10.09982401251864, -11.555749559377603, -12.115212556505885, -13.253032734309155, -14.171195402001418, -12.1676089605368, -11.470815428846048, -10.720101191679875, -10.543701992211332, -11.865073482281407, -9.897170048892079, -10.371847861659639, -10.113100643167202, -10.903242536628053, -12.042613291568212, -10.361032879138296, -9.409620503770624, -10.217022380203929, -10.618849346811732, -10.244477474746217, -10.003441913513418, -9.989286328037553, -10.027079366929287, -11.77446092356396, -9.082566958604971, -10.080402911082059, -10.623937873052972, -9.998956450366377, -13.085509437173878, -14.75507532292247, -12.432272183152538, -11.896607978514396, -10.116277207877525, -10.728260930556761, -12.616335998771495, -9.951707510718341, -11.400129907957746, -11.914464247343968, -13.291451648562166, -10.151666280666666, -10.722996079754804, -11.088524750799275, -11.599097643611737, -11.01970202106794, -10.624840646995242, -10.438314117302372, -8.633677046491218, -10.021750958383958, -10.210605300869917, -11.74041763667208, -10.590393474957745, -10.298445518184124, -11.687945445112428, -11.083011913018673, -12.25526599067916, -12.410756127719017, -11.269575375147953, -10.29294591057943, -10.876187332138242, -11.250669714214673, -13.649008043741743, -15.657631282034334, -13.470139164485051, -216.85327071268233, -276.2802090143159, -272.27163446074616, -75.55844725717462, -13.472595605074783, -200.0990066784966, -22.59698275502064, -14.275266231765043, -11.119114572195402, -12.169149375922485, -12.486357277730574, -9.351752683915208, -10.676316833319147, -12.64043860342795, -11.55815802633909, -10.581553149956587, -10.323925186263562, -9.358539409486065, -10.667308282207358, -8.894029570748748, -10.14396320256988, -12.386682843075492, -9.535411899165691, -10.834239471078389, -9.680304970133392, -11.589593370630988, -11.08787415567816, -9.265829559510715, -9.983266232158549, -10.62612064528389, -10.419707201974044, -9.458043524068668, -9.41167829745556, -10.939427797998448, -12.130652566949422, -8.34851803321859, -12.166350279351285, -10.874439750632115, -10.08642353818228, -10.27031265271527, -9.74325784708002, -11.854626161685827, -9.65911410146196, -10.109896934034806, -11.290728952816567, -9.627214975482017, -10.98785023165415, -9.272861796988273, -10.857923586574962, -8.454283312512423, -11.30009623106026, -10.622696758799723, -8.90591469350432, -8.330120086480335, -11.077085431500189, -10.319473128848598, -10.13139717856214, -10.322352587882436, -10.19664615784531, -11.4402467131168, -9.956185230271194, -11.91824194525325, -13.758042923971388, -11.169352113190891, -12.127517000348519, -10.735251840118902, -11.810210818264338, -9.085354056826798, -8.410031765457482, -11.765610779935098, -10.834125534906615, -10.440925468601417, -11.277111246461986, -11.429497200481109, -12.686396877195055, -11.269306051807035, -10.456524949978155, -11.29910013337429, -10.521879535998927, -10.455660957552464, -9.379402697902146, -7.665011535155808, -8.854164965657079, -8.860091508693223, -9.545477418495382, ...

# %%
# Plotting test progress:
West_queue = list()
South_queue= list()
East_queue = list()
North_queue= list()
# Queue Lengths
plt.figure(figsize=(8,4.5))
x_series = range(1,len(Agents[0].queues_over_time)+1)
for i in range(len(Agents[0].queues_over_time)):
    West_queue.append(Agents[0].queues_over_time[i][0])
    South_queue.append(Agents[0].queues_over_time[i][1])
    East_queue.append(Agents[0].queues_over_time[i][2])
    North_queue.append(Agents[0].queues_over_time[i][3])
plt.plot(x_series, West_queue, '-b',\
         x_series, South_queue, '-r',\
         x_series, East_queue, '-g',\
         x_series, North_queue, '-y')
plt.xlabel('Time [s]')
plt.ylabel('Queue Length')
plt.title('Training evolution and trend')
plt.gca().legend(('West Queue','South Queue', 'East Queue', 'North Queue'))
plt.show()

# Accumulated delay over time
plt.figure(figsize=(8,4.5))
x_series = range(1,len(Agents[0].accumulated_delay)+1)
plt.plot(x_series,Agents[0].accumulated_delay, '-b')
plt.xlabel('Time [s]')
plt.ylabel('Accumulated global Delay')
plt.title('Global Delay')
plt.gca().legend('GLlobal accumulated delay')
plt.show()

average_queue_length = np.mean(Agents[0].queues_over_time)
print("Average queue size is {}".format(np.round(average_queue_length,2)))
# Out:
# Average queue size is 6.01
