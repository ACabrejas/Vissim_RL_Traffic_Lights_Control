# %%
'''
You are going to test everything works

MasterAC_Agent
    init
        ACAgent(General_Agent)
        
    train
        environment
    
    test
        environment
    
    demo
        environment
    
    save
    
    load

---
General_Agent
-->
RLAgent 

    init 

    save_agent

    load_agent

    best_agent

    save_integrated_agent

    load_isolated_agent

    load_integrated_agent
  
---
ACAgent
    init
        Model2

    remember

    reset

    update_IDS

    reduce_entropy

    test

    value_check

    _value_loss

    _logits_loss

    _returns_advantages

    choose_action

    learn
    
Model2   
    __init__
        ProbabilityDistribution()

    call

    action_value

ProbabilityDistribution
    call


---

environment
    init
    
    _Load_SCUs
    
    get_state
    
    get_queues
    
    get_delays
    
    get_stop_delays
    
    get_delay_timestep
    
    get_stop_delay_timestep
    
    step
    
    step_to_next_action
    
    test
    
    Stop_Simulation
    
    reset
    
    change_demand
    
    select_mode
 
NetworkParser

---

COMServerDispatch


COMServerReload
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    



'''

# %%
import Actor_critic_class
import General_agent
import MasterAC_Agent
import Vissim_SCU_class
import Vissim_env_class
