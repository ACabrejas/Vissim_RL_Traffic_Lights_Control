# %%
from Vissim_env_class import environment, Load_Vissim
# Out:
#   File "<ipython-input-2-d77e36511c1e>", line 1
#     from ../Vissim_env_class import environment, Load_Vissim
#            ^
# SyntaxError: invalid syntax
